# %%
import os
import weaviate
import weaviate.classes as wvc
import requests
import requests
import json
from tqdm import tqdm
from weaviate.classes.config import Configure, Property, DataType
import re

# %%
url = "https://llm.srv.webis.de/api/embeddings"

path_to_data = "/home/rag/Downloads/msmarco_v2.1_doc_segmented_00.json"

model_name = "all-minilm"
#model_name = "llama3:70b"

# %%
client = weaviate.connect_to_local(
    port=8080,
    grpc_port=50051)

# %% [markdown]
# # Population

# %%
def llm_generator(segment):
    prompt = f"I am going to give you a chunk. You will generate 5 possible questions for the given chunk. The chunk is: {segment}"
    url = "https://llm.srv.webis.de/api/generate"
    data = {
        "model": "llama3",
        "prompt": prompt,
        "stream": False
    }
    try:
        response = requests.post(url, json=data)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return None
    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
def question_extractor(llm_response):
    text = llm_response["response"]

    pattern = r'\d+\.\s(.+?)(?=\n\d+\.|\Z)'

    questions = re.findall(pattern, text)

    return questions

# %%
client.collections.create(
    "mini_data_segment_hyde",
    properties=[  # Define properties
        Property(name="docid", data_type=DataType.TEXT),
        Property(name="url", data_type=DataType.TEXT),
        Property(name="title", data_type=DataType.TEXT),
        Property(name="headings", data_type=DataType.TEXT),
        Property(name="h_question", data_type=DataType.TEXT),
        Property(name="segment", data_type=DataType.TEXT),
        Property(name="start_char", data_type=DataType.INT),
        Property(name="end_char", data_type=DataType.INT),
    ],
    vectorizer_config=[
        # Set a named vector
        Configure.NamedVectors.text2vec_transformers(  # Use the "text2vec-cohere" vectorizer
            name="question", source_properties=["h_question"]       # Set the source property(ies)
        ),
        # Set another named vector
        Configure.NamedVectors.text2vec_transformers(  # Use the "text2vec-openai" vectorizer
            name="segment", source_properties=["segment"]         # Set the source property(ies)
        )
    ],
)

# %%
object_list = []   
with open(path_to_data, 'rb') as f:
    # Iterate over the objects
    for line_number, object in enumerate(f):
        json_obj = json.loads(object)

        """embedding_response = requests.post(url, json={"model": model_name,
                                                    "prompt": object["segment"],
                                                    }).json()"""
        


        #webis llama70b generates the related questions based on segment
        llm_response = llm_generator(json_obj["segment"])
        h_questions = question_extractor(llm_response)

        for q in h_questions:
            sample_object = {
                'docid': json_obj["docid"], 
                'url': json_obj["url"], 
                'title': json_obj["title"], 
                'headings': json_obj["headings"], 
                'segment': json_obj["segment"], 
                'start_char': json_obj["start_char"], 
                'end_char': json_obj["end_char"], 
                'h_question': q,
                }
        
            object_list.append(sample_object)
        if line_number == 200:
            break

# %%
print(len(object_list))
c=0
for object in object_list:
    c=c+1
    print(object)
    if(c==10):
        break
# Out:
# 747
# {'docid': 'msmarco_v2.1_doc_00_0#0_0', 'url': 'http://0-60.reviews/0-60-times/', 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'headings': '0-60 Times\n0-60 Times', 'segment': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews\n0-60 Times\nThere are many ways to measure the power a vehicle has – top speed, horsepower, foot-pounds of torque. Those are all important, but the most asked question is, “What’s the 0-60 time?” This is nothing more than a measure of how quickly a vehicle can reach the 60 mile per hour mark. It is a measure of acceleration of a vehicle. 0-60 times differ a great deal depending on the amount of power a motor puts out, of course. But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version.', 'start_char': 0, 'end_char': 1278, 'h_question': "What is the significance of a vehicle's 0-60 time in measuring its power?"}
# {'docid': 'msmarco_v2.1_doc_00_0#0_0', 'url': 'http://0-60.reviews/0-60-times/', 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'headings': '0-60 Times\n0-60 Times', 'segment': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews\n0-60 Times\nThere are many ways to measure the power a vehicle has – top speed, horsepower, foot-pounds of torque. Those are all important, but the most asked question is, “What’s the 0-60 time?” This is nothing more than a measure of how quickly a vehicle can reach the 60 mile per hour mark. It is a measure of acceleration of a vehicle. 0-60 times differ a great deal depending on the amount of power a motor puts out, of course. But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version.', 'start_char': 0, 'end_char': 1278, 'h_question': "How does a car's 0-60 time differ from its quarter mile time, and which one is considered more accurate for measuring acceleration?"}
# {'docid': 'msmarco_v2.1_doc_00_0#0_0', 'url': 'http://0-60.reviews/0-60-times/', 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'headings': '0-60 Times\n0-60 Times', 'segment': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews\n0-60 Times\nThere are many ways to measure the power a vehicle has – top speed, horsepower, foot-pounds of torque. Those are all important, but the most asked question is, “What’s the 0-60 time?” This is nothing more than a measure of how quickly a vehicle can reach the 60 mile per hour mark. It is a measure of acceleration of a vehicle. 0-60 times differ a great deal depending on the amount of power a motor puts out, of course. But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version.', 'start_char': 0, 'end_char': 1278, 'h_question': "Why do car enthusiasts place so much emphasis on a vehicle's 0-60 time when discussing its performance?"}
# {'docid': 'msmarco_v2.1_doc_00_0#0_0', 'url': 'http://0-60.reviews/0-60-times/', 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'headings': '0-60 Times\n0-60 Times', 'segment': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews\n0-60 Times\nThere are many ways to measure the power a vehicle has – top speed, horsepower, foot-pounds of torque. Those are all important, but the most asked question is, “What’s the 0-60 time?” This is nothing more than a measure of how quickly a vehicle can reach the 60 mile per hour mark. It is a measure of acceleration of a vehicle. 0-60 times differ a great deal depending on the amount of power a motor puts out, of course. But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version.', 'start_char': 0, 'end_char': 1278, 'h_question': 'In what way does the measurement of 0-60 times differ between the United States and other countries?'}
# {'docid': 'msmarco_v2.1_doc_00_0#0_0', 'url': 'http://0-60.reviews/0-60-times/', 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'headings': '0-60 Times\n0-60 Times', 'segment': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews\n0-60 Times\nThere are many ways to measure the power a vehicle has – top speed, horsepower, foot-pounds of torque. Those are all important, but the most asked question is, “What’s the 0-60 time?” This is nothing more than a measure of how quickly a vehicle can reach the 60 mile per hour mark. It is a measure of acceleration of a vehicle. 0-60 times differ a great deal depending on the amount of power a motor puts out, of course. But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version.', 'start_char': 0, 'end_char': 1278, 'h_question': "What are some factors that can affect a car's quarter mile time, making it less reliable for measuring acceleration than its 0-60 time?"}
# {'docid': 'msmarco_v2.1_doc_00_0#1_1557', 'url': 'http://0-60.reviews/0-60-times/', 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'headings': '0-60 Times\n0-60 Times', 'segment': 'But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version. But both measure the performance of a car. A lot goes into increasing 0-60 times in performance vehicles. As a normal rule of thumb, performance cars are considered those with 0-60 time of under 6 seconds, while Exotic cars will do 0-60 in 3 to 4 seconds. However, in most cases, a car isn’t simply “stuck with” the acceleration number with which it was born. Engineers and designers work tirelessly to provide better and better numbers with each progressive model of performance and exotic cars.', 'start_char': 508, 'end_char': 1775, 'h_question': "What is the common metric used by car enthusiasts to measure a car's power, according to the text?"}
# {'docid': 'msmarco_v2.1_doc_00_0#1_1557', 'url': 'http://0-60.reviews/0-60-times/', 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'headings': '0-60 Times\n0-60 Times', 'segment': 'But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version. But both measure the performance of a car. A lot goes into increasing 0-60 times in performance vehicles. As a normal rule of thumb, performance cars are considered those with 0-60 time of under 6 seconds, while Exotic cars will do 0-60 in 3 to 4 seconds. However, in most cases, a car isn’t simply “stuck with” the acceleration number with which it was born. Engineers and designers work tirelessly to provide better and better numbers with each progressive model of performance and exotic cars.', 'start_char': 508, 'end_char': 1775, 'h_question': 'How does the quarter mile time compare to the 0-60 mph speed in measuring acceleration, and why might one be considered less accurate than the other?'}
# {'docid': 'msmarco_v2.1_doc_00_0#1_1557', 'url': 'http://0-60.reviews/0-60-times/', 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'headings': '0-60 Times\n0-60 Times', 'segment': 'But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version. But both measure the performance of a car. A lot goes into increasing 0-60 times in performance vehicles. As a normal rule of thumb, performance cars are considered those with 0-60 time of under 6 seconds, while Exotic cars will do 0-60 in 3 to 4 seconds. However, in most cases, a car isn’t simply “stuck with” the acceleration number with which it was born. Engineers and designers work tirelessly to provide better and better numbers with each progressive model of performance and exotic cars.', 'start_char': 508, 'end_char': 1775, 'h_question': 'Why do some countries prefer the 0-100 km version over the standard 0-60 mph measure used in the United States?'}
# {'docid': 'msmarco_v2.1_doc_00_0#1_1557', 'url': 'http://0-60.reviews/0-60-times/', 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'headings': '0-60 Times\n0-60 Times', 'segment': 'But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version. But both measure the performance of a car. A lot goes into increasing 0-60 times in performance vehicles. As a normal rule of thumb, performance cars are considered those with 0-60 time of under 6 seconds, while Exotic cars will do 0-60 in 3 to 4 seconds. However, in most cases, a car isn’t simply “stuck with” the acceleration number with which it was born. Engineers and designers work tirelessly to provide better and better numbers with each progressive model of performance and exotic cars.', 'start_char': 508, 'end_char': 1775, 'h_question': 'What is the typical benchmark for classifying a car as performance-oriented versus exotic, based on its 0-60 time?'}
# {'docid': 'msmarco_v2.1_doc_00_0#1_1557', 'url': 'http://0-60.reviews/0-60-times/', 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'headings': '0-60 Times\n0-60 Times', 'segment': 'But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version. But both measure the performance of a car. A lot goes into increasing 0-60 times in performance vehicles. As a normal rule of thumb, performance cars are considered those with 0-60 time of under 6 seconds, while Exotic cars will do 0-60 in 3 to 4 seconds. However, in most cases, a car isn’t simply “stuck with” the acceleration number with which it was born. Engineers and designers work tirelessly to provide better and better numbers with each progressive model of performance and exotic cars.', 'start_char': 508, 'end_char': 1775, 'h_question': "How do engineers and designers typically work to improve a car's acceleration numbers from one model generation to the next?"}

# %%
collection=client.collections.get("mini_data_segment_hyde")
with collection.batch.dynamic() as batch:
        for d in object_list:
            properties={
            "docid":d["docid"],
            "url":d["url"],
            "title":d["title"],
            "headings":d["headings"],
            "segment":d["segment"],
            "start_char":d["start_char"],
            "end_char":d["end_char"],
            "h_question":d["h_question"]
            }
            batch.add_object(properties)

# %%
with open('output.json','w') as file:
    json.dump(object_list,file,indent=4)

# %% [markdown]
# # Evaluation

# %%
from weaviate.classes.query import MetadataQuery

mini_collection = client.collections.get("mini_data_segment_hyde")

# %%
def retrieve_segments(topic,num_segments, target_vector):
    return mini_collection.query.near_text(query=topic,
                                              limit=num_segments,
                                              target_vector=target_vector,
                                              return_metadata=MetadataQuery(certainty=True))
#a function that takes a list of retrieval objects with duplicates
#and returns distinct results with the top 5 certainty score(cosine)
def trim_segments(retrieval_result):
    already_retrieved_ids = []
    distinct_segments = []
    for o in retrieval_result.objects:
            if o.properties["docid"] not in already_retrieved_ids:
                already_retrieved_ids.append(o.properties["docid"])
                distinct_segments.append(o)
                #only get top 5 similar
                if len(distinct_segments)== 5:
                    break

    return distinct_segments

# %%
topics = '/home/rag/Desktop/project-rag-ss24/src/Data/topics.msmarco-v2-doc.dev2.txt'

eval_dic = {}

with open(topics, 'r') as file:
    for line in file:
        try:
            id_, topic = line.split('\t')
            id_ = id_.strip()
            topic = topic.strip()
            #25 because we will evaluate based on 5 most similar segments and 
            #every segment has 5 hypothetical questions it is indexed through
            segment_result = retrieve_segments(topic, 25, "segment")
            question_result = retrieve_segments(topic, 25, "question")
        
            #this will ensure only topics with related segments to be put in the eval dictionary
            if (segment_result.objects[0].metadata.certainty < 0.80) & (question_result.objects[0].metadata.certainty < 0.80):
                pass
            else:
            
                segment_distinct_segments = trim_segments(segment_result)
                question_distinct_segments = trim_segments(question_result)
                
                eval_dic[topic] = {"nonhyde" : segment_distinct_segments,
                                "hyde": question_distinct_segments}
        except:
            print(line)

# %%
eval_dic
# Out:
# {'what is function of registry': {'nonhyde': [Object(uuid=_WeaviateUUIDInt('d9ba5f46-6191-46eb-98a7-f15075e16b05'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7431946396827698, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 3306, 'url': 'http://00000.extensionfile.net/', 'segment': "Open 00000 file article translations\nFor more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating\nsystems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System\nRegistry, review some possible attacks to it and ways to avoid them...\nFolders, files and paths- Files are the entries or information stored on your\ncomputer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by\nMicrosoft with their products including system files for their series of operating systems...\nWhat are file extensions? - File extensions are unnoticed yet are very crucial parts of\nthe computer world. But many are still unaware of the basic foundation and principles behind the remarkable wonders of computers...\n© Copyright 2021 extensionfile.net Privacy Policy. Terms of Service", 'h_question': 'How can users avoid attacks on their Windows system registry, and what are some common threats to be aware of?', 'title': '', 'end_char': 4393, 'docid': 'msmarco_v2.1_doc_00_32860#6_69086'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('fc75297b-11bc-4fe4-9c7b-0b24f9ddbd34'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.6820136308670044, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 2823, 'end_char': 4133, 'segment': "Install the application you found and check if it can open 00000 file\nRate 00000 filepage: 54321 \n4/5based on 27ratings\nPopulating this website with information and maintaining it is an ongoing process. We always welcome feedback and questions that can be submitted by visiting Contact Us page. However since there are many users visiting this website and because our team is quite small we may not be able to follow up personally on every request. Thank you for your understanding. Open 00000 file article translations\nFor more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating\nsystems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System\nRegistry, review some possible attacks to it and ways to avoid them...\nFolders, files and paths- Files are the entries or information stored on your\ncomputer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by\nMicrosoft with their products including system files for their series of operating systems...\nWhat are file extensions? -", 'h_question': 'What is the purpose of installing an application and checking if it can open a 00000 file?', 'title': '', 'url': 'http://00000.extensionfile.net/', 'docid': 'msmarco_v2.1_doc_00_32860#5_67594'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('5560a772-1049-48f0-a159-f4ac28a8fd91'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.6575680375099182, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': 'Examples and Non-Examples\nExamples and Non-Examples', 'start_char': 3428, 'url': 'http://0051b07.netsolhost.com/index.php/more-info/sdsu/23-sped-450/2215-examples-and-non-examples', 'segment': 'Comprehend level. Click on the activity hyperlink for a list of procedures to follow for using the activity. Activity Example or Non-Example? Purpose and Description\nThe purpose of this activity is to allow students to practice classifying defined concepts. Students are given instances that represent Examples and Non-Examples. They must correctly name the defined concept described. Format\nClass\nPreparation and Materials Required\n__________________________________________________________________________________________________________\nList of Examples and Non-Examples for the defined concepts\nInstructor presentation materials\nExample and Non-Example Creation\nThe purpose of this activity is to allow students to practice comprehending the characteristics of the defined concepts by creating Examples and Non-Examples of the defined concepts. Format\nIndividual\nPairs\nSmall group\nPreparation and Materials Required\nHandouts of a list of defined concepts\nStudent presentation materials\n__________________________________________________________________________________________________________\nNarrative Generation from Examples and Non-Examples\nThe purpose of this activity is to allow students to practice and test their understanding of the characteristics of the defined concepts by creating narratives from a list of Examples and Non-Examples that summarize the lesson content. Format\nIndividual\nPairs\nSmall group\nPreparation and Materials Required\nHandouts of Examples and Non-Examples of the defined concepts\n_________________________________________________________________________________________________________\nProcedures for Example or Non-Example? 1.', 'h_question': 'What format(s) can be used for completing the "Comprehend level" activity, as listed in the preparation and materials required section?', 'title': 'Examples and Non-Examples', 'end_char': 5094, 'docid': 'msmarco_v2.1_doc_00_155044#8_253449'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('dd68ce78-2873-47f6-9646-bce0e8cb9b89'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.640792727470398, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': 'Open 00J File\nOpen 00J File\nHow to Open 00J file\nWhat is 00J File?\n00J File Applications\n', 'start_char': 689, 'url': 'http://00j.extensionfile.net/', 'segment': 'What is 00J File? File extensions help computers locate correct application for specific files. Operating systems will not look into the content of the files to be opened, but instead, it will immediately locate the file extension of the file and locate for associated application that can open 00J files. This helps the computer to organize its functions and work much faster. Most operating systems (Windows) require the use of file extensions, but others do not (Unix). These file extensions are also beneficial for us. By simply looking at the filename, we can determine what type of information is stored to that and what applications can open these files. Have you noticed that when your computer acquires an unknown file, it will ask your permission to look for associated program to open it or look for these programs over the Internet? Yes! These file extensions make the work of the computer easy.', 'h_question': 'Why is it important for operating systems like Windows to use file extensions?', 'title': 'Open 00J File', 'end_char': 1597, 'docid': 'msmarco_v2.1_doc_00_209130#1_296695'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('fdd8c282-cdcd-46fe-a595-3e98dced05d5'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.6338517665863037, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': 'Open 00001 File\nOpen 00001 File\nHow to Open 00001 file\nWhat is 00001 File?\n00001 File Applications\n', 'start_char': 563, 'url': 'http://00001.extensionfile.net/', 'segment': 'If there is no application on your computer which can open 00001 files you need to search on the internet which application can open 00001 files. What is 00001 File? File extensions help computers locate correct application for specific files. Operating systems will not look into the content of the files to be opened, but instead, it will immediately locate the file extension of the file and locate for associated application that can open 00001 files. This helps the computer to organize its functions and work much faster. Most operating systems (Windows) require the use of file extensions, but others do not (Unix). These file extensions are also beneficial for us. By simply looking at the filename, we can determine what type of information is stored to that and what applications can open these files. Have you noticed that when your computer acquires an unknown file, it will ask your permission to look for associated program to open it or look for these programs over the Internet? Yes!', 'h_question': 'How do computers locate the correct application to open a specific file?', 'title': 'Open 00001 File', 'end_char': 1563, 'docid': 'msmarco_v2.1_doc_00_37424#1_71741'}, references=None, vector={}, collection='Mini_data_segment_hyde')],
#   'hyde': [Object(uuid=_WeaviateUUIDInt('c2e0331c-86fd-4b38-8877-5b669ed8f6ef'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.8076457977294922, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 3306, 'end_char': 4393, 'segment': "Open 00000 file article translations\nFor more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating\nsystems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System\nRegistry, review some possible attacks to it and ways to avoid them...\nFolders, files and paths- Files are the entries or information stored on your\ncomputer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by\nMicrosoft with their products including system files for their series of operating systems...\nWhat are file extensions? - File extensions are unnoticed yet are very crucial parts of\nthe computer world. But many are still unaware of the basic foundation and principles behind the remarkable wonders of computers...\n© Copyright 2021 extensionfile.net Privacy Policy. Terms of Service", 'h_question': 'What is the purpose of the Windows registry, and how does it differ from older INI files?', 'title': '', 'url': 'http://00000.extensionfile.net/', 'docid': 'msmarco_v2.1_doc_00_32860#6_69086'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('b17d0833-47d9-4882-a259-d548e6805225'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7454531788825989, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 2823, 'url': 'http://00000.extensionfile.net/', 'segment': "Install the application you found and check if it can open 00000 file\nRate 00000 filepage: 54321 \n4/5based on 27ratings\nPopulating this website with information and maintaining it is an ongoing process. We always welcome feedback and questions that can be submitted by visiting Contact Us page. However since there are many users visiting this website and because our team is quite small we may not be able to follow up personally on every request. Thank you for your understanding. Open 00000 file article translations\nFor more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating\nsystems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System\nRegistry, review some possible attacks to it and ways to avoid them...\nFolders, files and paths- Files are the entries or information stored on your\ncomputer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by\nMicrosoft with their products including system files for their series of operating systems...\nWhat are file extensions? -", 'h_question': 'Why is the Windows registry considered an important part of modern operating systems, replacing older INI files?', 'title': '', 'end_char': 4133, 'docid': 'msmarco_v2.1_doc_00_32860#5_67594'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('fc9b4a97-3a5c-415b-bf04-567c4b8de02b'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.6477391719818115, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': "Riverdale High\nRiverdale High\nTimes for the High School Schedule\nReport to your teacher’s Google Classroom ready and on time to be amazing. #GoRaiders #DaleBuilt\nCOVID 19 Vaccination Flyers\nPlease be sure to check out the information that CCPS is making available to students, families, and the community.\nFlyers are available in English | Spanish | Vietnamese\nSeniors >>> Class of 2021\nHERFF JONES WILL BE HERE!!!\nCap and Gown Delivery\nMarch 10 - 3 to 5 pm\nApril 28 - 2 to 5 pm\nPlease aim to pick up your regalia on these dates. Otherwise, you'd need to pick them up from the Herff Jones office.\nYour Input Matters\nMonthly and Weekly Calendar of Activities and Events\nBelow are links to the monthly and weekly calendar of events and activities.\nTitle I Calendar\nApril 26-30\nSenior Newsletter\nStudent Handbook\nParents and Students,\nPlease download the student handbook linked below. There are 3 different versions – English, Spanish, and Vietnamese. Additionally, please complete the form that serves acknowledgement of your receipt and review of the student handbook.\nEnglish | Spanish | Vietnamese\nAcknowledgment Form\nMeal Services Announcement\nBreakfast and Lunch is Served!\nAll CCPS students may receivemeals at the school bus stop closest to their home (see CCPS Transportation website) or curbside at the nearest school (9 am – Noon) . Breakfast and lunch meals will be served at the same time.Only CCPS students are eligible to receive meals. StudentID numbers may be required to identify students. Parents/guardians may pick up meals for students.\nAttendance Matters\nPlease make sure that documentation related to student absences needs to be emailed or faxed to our attendance clerk – Connie Young.\nConnie Young, Attendance Clerk\nconnie.young@clayton.k12.ga.us\n770-473-2905 ex. 505124\n770-473-2913 fax\nStudents will be marked tardy if they are 6 minutes late to their virtual classes.\nCameras are required to be on during SEL (social-emotional learning) and Live instruction (20-25 mins). If a teacher is unable to see or no responses are given when called, that will lead to the student being marked absent.\nParents and families, please remember to check your parent portal to view your child’s attendance and grades.\nOnline Registration System\nSince May 2020, Clayton County Public Schools (CCPS) has been offering anOnlineRegistration\n(OLR) process for students who areregisteringfor new/returning students who arenot currently enrolled with CCPS for the 2020-2021 school year. For more information regarding 2020-2021 Online Registration, please view the video at http://youtu.be/cct5TjGH7Twor visit the CCPS website (http://www.clayton.k12.ga.us).\nRegistration Central Page\nhttps://www.clayton.k12.ga.us/cms/One.aspx?portalId=54515&pageId=237811\nCCPS Withdrawal Request Google Form\nFor more information about counseling related topics, please visit the counseling page.\nOnline Textbooks and Digital Resources\nWe are working to make sure that all students and parents have access to textbooks and resources. As info, there are two documents you can reference. The first is the CCPS flyer about available resources. The second provides resources available for our students and parents at RHS. CCPS Flyer\nReminders for Students and Parents\nPlease join the Remind classes below to get updates:\nClass of 2021:\nhttps://www.remind.com/join/ad2a6c\nClass of 2022:\nhttps://www.remind.com/join/86b33c\nClass of 2023:\nhttps://www.remind.com/join/dbdhb8\nClass of 2024:\nhttps://www.remind.com/join/g7ea74\nContact Us\nDonna Thompson, 9th Grade Counselor\ndonna.thompson@clayton.k12.ga.us\n770.648.4457\nGoogle Classroom Code: 7peytsa\nKansas Cooley, 12th Grade Coun ...
#    Object(uuid=_WeaviateUUIDInt('47fe0bb8-fccb-4cf7-8823-bbff66cfd6d5'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.6451333165168762, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': 'Examples and Non-Examples\nExamples and Non-Examples', 'start_char': 5095, 'url': 'http://0051b07.netsolhost.com/index.php/more-info/sdsu/23-sped-450/2215-examples-and-non-examples', 'segment': 'Explain that the purpose of this activity is to practice comprehending the characteristics of the defined concepts presented by classifying Examples and Non-Examples of the defined concepts. 2. Present a new Example or Non-Example (that has not been previously presented to students) of the defined concept from the list. 3. Have students determine if it is an Example or Non-Example and explain what characteristics make it an Example or Non-Example. 4. Provide feedback for the answer. 5. Repeat steps 2-4 until the students have correctly identified every defined concept from the list. 6.', 'h_question': 'What is the main purpose of this activity in the context of learning about defined concepts?', 'title': 'Examples and Non-Examples', 'end_char': 5687, 'docid': 'msmarco_v2.1_doc_00_155044#10_257583'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('45084f31-1f27-4898-8ecd-546df171e2e5'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.640036940574646, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': 'Open 00J File\nOpen 00J File\nHow to Open 00J file\nWhat is 00J File?\n00J File Applications\n', 'start_char': 689, 'end_char': 1597, 'segment': 'What is 00J File? File extensions help computers locate correct application for specific files. Operating systems will not look into the content of the files to be opened, but instead, it will immediately locate the file extension of the file and locate for associated application that can open 00J files. This helps the computer to organize its functions and work much faster. Most operating systems (Windows) require the use of file extensions, but others do not (Unix). These file extensions are also beneficial for us. By simply looking at the filename, we can determine what type of information is stored to that and what applications can open these files. Have you noticed that when your computer acquires an unknown file, it will ask your permission to look for associated program to open it or look for these programs over the Internet? Yes! These file extensions make the work of the computer easy.', 'h_question': 'What is the primary function of file extensions in computers?', 'title': 'Open 00J File', 'url': 'http://00j.extensionfile.net/', 'docid': 'msmarco_v2.1_doc_00_209130#1_296695'}, references=None, vector={}, collection='Mini_data_segment_hyde')]},
#  'what is the fastest car in the?': {'nonhyde': [Object(uuid=_WeaviateUUIDInt('db10340e-cb48-460c-85a8-eb115777cc34'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.826582670211792, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '0-60 Times\n0-60 Times', 'start_char': 508, 'end_char': 1775, 'segment': 'But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version. But both measure the performance of a car. A lot goes into increasing 0-60 times in performance vehicles. As a normal rule of thumb, performance cars are considered those with 0-60 time of under 6 seconds, while Exotic cars will do 0-60 in 3 to 4 seconds. However, in most cases, a car isn’t simply “stuck with” the acceleration number with which it was born. Engineers and designers work tirelessly to provide better and better numbers with each progressive model of performance and exotic cars.', 'h_question': 'How does the quarter mile time compare to the 0-60 mph speed in measuring acceleration, and why might one be considered less accurate than the other?', 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'url': 'http://0-60.reviews/0-60-times/', 'docid': 'msmarco_v2.1_doc_00_0#1_1557'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('4e179fe3-2d69-4db5-97b9-c3fcee40caf7'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.784464955329895, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '0-60 Times\n0-60 Times', 'start_char': 1279, 'end_char': 2381, 'segment': 'But both measure the performance of a car. A lot goes into increasing 0-60 times in performance vehicles. As a normal rule of thumb, performance cars are considered those with 0-60 time of under 6 seconds, while Exotic cars will do 0-60 in 3 to 4 seconds. However, in most cases, a car isn’t simply “stuck with” the acceleration number with which it was born. Engineers and designers work tirelessly to provide better and better numbers with each progressive model of performance and exotic cars. But, even the back yard mechanic or muscle car enthusiast can determine the 0-60 times of their cars and make moves to improve them. The testing of acceleration is usually done on a closed course away from people other than the team that may be working on the specific car. This limits putting anyone in danger who is not part of the test or the ongoing project. Testers can use something as simple as a stop watch and the vehicle’s speedometer. This is probably good enough for the typical muscle car enthusiast who is just looking for an estimate of how much power his latest improvements will give him.', 'h_question': "How can a DIY enthusiast or muscle car owner estimate their car's 0-60 time without professional testing equipment?", 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'url': 'http://0-60.reviews/0-60-times/', 'docid': 'msmarco_v2.1_doc_00_0#2_3101'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('46a2f005-3c70-4f20-934f-e7a212c814da'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.782470166683197, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '0-60 Times\n0-60 Times', 'start_char': 0, 'url': 'http://0-60.reviews/0-60-times/', 'segment': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews\n0-60 Times\nThere are many ways to measure the power a vehicle has – top speed, horsepower, foot-pounds of torque. Those are all important, but the most asked question is, “What’s the 0-60 time?” This is nothing more than a measure of how quickly a vehicle can reach the 60 mile per hour mark. It is a measure of acceleration of a vehicle. 0-60 times differ a great deal depending on the amount of power a motor puts out, of course. But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version.', 'h_question': "Why do car enthusiasts place so much emphasis on a vehicle's 0-60 time when discussing its performance?", 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'end_char': 1278, 'docid': 'msmarco_v2.1_doc_00_0#0_0'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('7fad0385-d02f-46d3-92a6-347c32befd3e'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7397179007530212, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '0-60 Times\n0-60 Times', 'start_char': 3581, 'url': 'http://0-60.reviews/0-60-times/', 'segment': 'Instead, some believe the measure should include a range of times rather than one finite mark to which all cars of any particular model should be held. For instance, they believe a BMW M3 should have a listed time of 3.9 – 4.2 seconds and a Corvette Z06 should have a range from 3.6 to 4.0. These people believe that a range of numbers better represents what an owner can honestly expect to see when he or she takes delivery of a new vehicle. This contingent of car enthusiasts and engineers believes that there is no way for either the time to 60 mph or even a quarter mile time to be completely accurate, as there are simply too many variables that come into play. No matter if you are a 0 – 60 purist, or you believe that it is an inexact science, you can be sure that the measure itself will not be going away any time soon. It is still one of the biggest touted numbers for vehicles, and easier for people to relate to than horsepower and torque.', 'h_question': 'How do proponents of measuring a range of times rather than a single number believe it better represents real-world performance?', 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'end_char': 4532, 'docid': 'msmarco_v2.1_doc_00_0#6_9130'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('3a1997e8-fae0-4fc0-8034-c9f1c76e45ec'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7006573677062988, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '0-60 Times\n0-60 Times', 'start_char': 2997, 'end_char': 4409, 'segment': 'The average of these two times will be the recorded 0-60 time for the car. Doppler radar guns are used to ensure the tester is recording exact 0 -60 times. This leaves the driver to focus solely on running through the gears as precisely as possible and simply driving in a straight line. This allow for a more accurate measure, as does running the test first in one direction and then in the exact opposite direction. Some still feel, however, that listing one 0 – 60 time is not truly indicative of what a new owner can expect from a performance or exotic car, or even a muscle car. Instead, some believe the measure should include a range of times rather than one finite mark to which all cars of any particular model should be held. For instance, they believe a BMW M3 should have a listed time of 3.9 – 4.2 seconds and a Corvette Z06 should have a range from 3.6 to 4.0. These people believe that a range of numbers better represents what an owner can honestly expect to see when he or she takes delivery of a new vehicle. This contingent of car enthusiasts and engineers believes that there is no way for either the time to 60 mph or even a quarter mile time to be completely accurate, as there are simply too many variables that come into play. No matter if you are a 0 – 60 purist, or you believe that it is an inexact science, you can be sure that the measure itself will not be going away any time soon.', 'h_question': "Do you agree or disagree with the idea that listing a range of times instead of a single time provides a more realistic expectation of a car's performance?", 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'url': 'http://0-60.reviews/0-60-times/', 'docid': 'msmarco_v2.1_doc_00_0#5_7440'}, references=None, vector={}, collection='Mini_data_segment_hyde')],
#   'hyde': [Object(uuid=_WeaviateUUIDInt('819ee65c-b1f1-4f8b-9aa1-301fd96f3c9d'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7787390351295471, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '0-60 Times\n0-60 Times', 'start_char': 508, 'url': 'http://0-60.reviews/0-60-times/', 'segment': 'But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version. But both measure the performance of a car. A lot goes into increasing 0-60 times in performance vehicles. As a normal rule of thumb, performance cars are considered those with 0-60 time of under 6 seconds, while Exotic cars will do 0-60 in 3 to 4 seconds. However, in most cases, a car isn’t simply “stuck with” the acceleration number with which it was born. Engineers and designers work tirelessly to provide better and better numbers with each progressive model of performance and exotic cars.', 'h_question': 'What is the typical benchmark for classifying a car as performance-oriented versus exotic, based on its 0-60 time?', 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'end_char': 1775, 'docid': 'msmarco_v2.1_doc_00_0#1_1557'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('8a24731c-7817-4b21-b4a2-b214fcffc9a2'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7160167694091797, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '0-60 Times\n0-60 Times', 'start_char': 0, 'url': 'http://0-60.reviews/0-60-times/', 'segment': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews\n0-60 Times\nThere are many ways to measure the power a vehicle has – top speed, horsepower, foot-pounds of torque. Those are all important, but the most asked question is, “What’s the 0-60 time?” This is nothing more than a measure of how quickly a vehicle can reach the 60 mile per hour mark. It is a measure of acceleration of a vehicle. 0-60 times differ a great deal depending on the amount of power a motor puts out, of course. But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version.', 'h_question': "How does a car's 0-60 time differ from its quarter mile time, and which one is considered more accurate for measuring acceleration?", 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'end_char': 1278, 'docid': 'msmarco_v2.1_doc_00_0#0_0'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('33b3dcb1-cad4-4113-95fb-6b9ba92cfb66'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7117319107055664, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '0-60 Times\n0-60 Times', 'start_char': 2382, 'end_char': 3580, 'segment': 'For engineers testing a new exotic sports car, though, a simple estimate is not accurate enough. They want hard and fast 0-60 times, and they use much more highly-technical equipment to get their numbers. With the 0-60 figure being so important in automobile sales, they do everything possible to ensure their numbers are incredibly accurate. In professional testing situations, highly technical and accurate measuring devices are hooked to computers as the test is performed. The test is run in two different directions, to eliminate any influence of wind, an unseen downhill grade or any differences in traction. The average of these two times will be the recorded 0-60 time for the car. Doppler radar guns are used to ensure the tester is recording exact 0 -60 times. This leaves the driver to focus solely on running through the gears as precisely as possible and simply driving in a straight line. This allow for a more accurate measure, as does running the test first in one direction and then in the exact opposite direction. Some still feel, however, that listing one 0 – 60 time is not truly indicative of what a new owner can expect from a performance or exotic car, or even a muscle car.', 'h_question': 'Why do some experts believe that listing one 0-60 time is not enough to represent the performance of an exotic or muscle car?', 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'url': 'http://0-60.reviews/0-60-times/', 'docid': 'msmarco_v2.1_doc_00_0#4_5974'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('1a33ef57-b193-492b-a9d3-92b9882f934c'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.6897644400596619, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '0-60 Times\n0-60 Times', 'start_char': 3581, 'end_char': 4532, 'segment': 'Instead, some believe the measure should include a range of times rather than one finite mark to which all cars of any particular model should be held. For instance, they believe a BMW M3 should have a listed time of 3.9 – 4.2 seconds and a Corvette Z06 should have a range from 3.6 to 4.0. These people believe that a range of numbers better represents what an owner can honestly expect to see when he or she takes delivery of a new vehicle. This contingent of car enthusiasts and engineers believes that there is no way for either the time to 60 mph or even a quarter mile time to be completely accurate, as there are simply too many variables that come into play. No matter if you are a 0 – 60 purist, or you believe that it is an inexact science, you can be sure that the measure itself will not be going away any time soon. It is still one of the biggest touted numbers for vehicles, and easier for people to relate to than horsepower and torque.', 'h_question': 'What is the main argument against using a single finite mark to measure 0-60 mph times in cars?', 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'url': 'http://0-60.reviews/0-60-times/', 'docid': 'msmarco_v2.1_doc_00_0#6_9130'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('4e179fe3-2d69-4db5-97b9-c3fcee40caf7'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.6721857786178589, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '0-60 Times\n0-60 Times', 'start_char': 1279, 'end_char': 2381, 'segment': 'But both measure the performance of a car. A lot goes into increasing 0-60 times in performance vehicles. As a normal rule of thumb, performance cars are considered those with 0-60 time of under 6 seconds, while Exotic cars will do 0-60 in 3 to 4 seconds. However, in most cases, a car isn’t simply “stuck with” the acceleration number with which it was born. Engineers and designers work tirelessly to provide better and better numbers with each progressive model of performance and exotic cars. But, even the back yard mechanic or muscle car enthusiast can determine the 0-60 times of their cars and make moves to improve them. The testing of acceleration is usually done on a closed course away from people other than the team that may be working on the specific car. This limits putting anyone in danger who is not part of the test or the ongoing project. Testers can use something as simple as a stop watch and the vehicle’s speedometer. This is probably good enough for the typical muscle car enthusiast who is just looking for an estimate of how much power his latest improvements will give him.', 'h_question': "How can a DIY enthusiast or muscle car owner estimate their car's 0-60 time without professional testing equipment?", 'title': '0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews', 'url': 'http://0-60.reviews/0-60-times/', 'docid': 'msmarco_v2.1_doc_00_0#2_3101'}, references=None, vector={}, collection='Mini_data_segment_hyde')]},
#  'definition of shelf life': {'nonhyde': [Object(uuid=_WeaviateUUIDInt('dbe7d997-5d5e-42bb-ab96-0394cdf25028'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7076284885406494, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 3021, 'end_char': 3837, 'segment': 'Let surface dry and then set it back up for the pet. Return the pet to the room. Are LA’s Totally Awesome All Purpose Cleaner ® containers recyclable? Please refer to the logo on the container. With a little bit of care much plastic can be recycled, and collection of plastics for recycling is increasing rapidly. The plastic industry has responded to this problem by developing a series of cryptic markers, commonly seen on the bottom of plastic containers. These markers do not mean the plastic can be recycled, these makers do not mean the container uses recycled plastic. You should place in your bin only those types of plastic listed by your local recycling agency! What is the shelf life of your products? All of our products are tested for a shelf life of a minimum of two years from the date of manufacture.', 'h_question': "Are LA's Totally Awesome All Purpose Cleaner containers recyclable, and if so, what specific plastic types can be recycled?", 'title': "LA's Totally Awesome Products - FAQs", 'url': 'http://004f876.netsolhost.com/html/faqs.html', 'docid': 'msmarco_v2.1_doc_00_116164#6_158764'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('239f83ee-4d51-4dac-b651-eec889fcc98f'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7073252201080322, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 3335, 'end_char': 4374, 'segment': 'The plastic industry has responded to this problem by developing a series of cryptic markers, commonly seen on the bottom of plastic containers. These markers do not mean the plastic can be recycled, these makers do not mean the container uses recycled plastic. You should place in your bin only those types of plastic listed by your local recycling agency! What is the shelf life of your products? All of our products are tested for a shelf life of a minimum of two years from the date of manufacture. However, we do recommend using the product within one year of opening it to guarantee freshness and efficacy. What is LA’s Totally Awesome All Purpose Cleaner ® made from? LA’s Totally Awesome All Purpose Cleaner ® is a blend of water, surfactant (surface-active) agents, color and scent. Surfactant agents lift grease and oil up off of the surface. LA’s Totally Awesome All Purpose Cleaner ® is a safe, naturally gentle soap, specially formulated for cleaning a variety of surfaces like floors, furniture, and other household surfaces.', 'h_question': 'Can you guarantee that using the product within one year of opening will always ensure its effectiveness?', 'title': "LA's Totally Awesome Products - FAQs", 'url': 'http://004f876.netsolhost.com/html/faqs.html', 'docid': 'msmarco_v2.1_doc_00_116164#7_159814'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('e9ad7d6b-85ca-4776-a148-6b0cb0b6d184'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.6150607466697693, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 2501, 'url': 'http://001yourtranslationservice.com/kenax/Translators/Resources/TimeZones.htm', 'segment': 'Muscat; Tblisi; Volgograd; Kabul\n+4:00\n13:00 – 21:00\nZP5\nChesapeake Bay\n+5:00\n14:00 – 22:00\nZP6\nChesapeake Bay\n+6:00\n15:00 – 23:00\nWAST\nWest Australian Standard\n+7:00\n16:00 – 24:00\nCCT\nChina Coast, Russia Zone 7, Hong Kong, Peking\n+8:00\n17:00 – 01:00\nJST\nJapan Standard, Russia Zone 8\n+9:00\n18:00 – 02:00\nGST\nGuam Standard, Russia Zone 9\n+10:00\n19:00 – 03:00\n\n\n+11:00\n20:00 – 04:00\nIDLE\nInternational Date Line East: Wellington, New\nZealand\n+12:00\n21:00 – 05:00\nNZST\nNew Zealand Standard: Fiji\n+12:00\n21:00 – 05:00\nNZT\nNew Zealand: Marshall\nIslands\n+12:00\n21:00 – 05:00\nTherefore, if something is due at 16:00 (4:00pm) GMT time, and you are located in Volgograd Russia on ZP4 time, you would have to deliver your work by 20:00 (8:00pm) your time (add four hours to the due date, according to the third column in the table above). Share|\nWhat are Time Zones? Well, we could ask what is time? To explain this, let us go\nto the beginning of what we can define as time.', 'h_question': 'What is the purpose of having different time zones?', 'title': '', 'end_char': 3466, 'docid': 'msmarco_v2.1_doc_00_39686#8_81164'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('9c9d0460-119f-4b88-a185-86342f3e00b5'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.5876338481903076, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 2989, 'end_char': 3937, 'segment': 'Fiji\n+12:00\n21:00 – 05:00\nNZT\nNew Zealand: Marshall\nIslands\n+12:00\n21:00 – 05:00\nTherefore, if something is due at 16:00 (4:00pm) GMT time, and you are located in Volgograd Russia on ZP4 time, you would have to deliver your work by 20:00 (8:00pm) your time (add four hours to the due date, according to the third column in the table above). Share|\nWhat are Time Zones? Well, we could ask what is time? To explain this, let us go\nto the beginning of what we can define as time. Let us presume that, before the big bang, there was only\nenergy, and no time. We can say that God was this energy. And "then" he decided\nto make things, so he converted this energy into massand hence was created the big bang, which was an explosion of the energy force turning\ninto matter. Exploding outwards in all directions, and creating the universe, or many\nuniverses, and therefore dimensions, where time is considered the fourth dimension. Everything is relative.', 'h_question': 'In what ways do the concepts of relativity and dimensions mentioned in the text influence our understanding of time zones and their practical applications?', 'title': '', 'url': 'http://001yourtranslationservice.com/kenax/Translators/Resources/TimeZones.htm', 'docid': 'msmarco_v2.1_doc_00_39686#9_82451'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('3154fc61-da76-4d21-b6b3-aaa147f4665a'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.5747343897819519, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 3838, 'url': 'http://004f876.netsolhost.com/html/faqs.html', 'segment': "However, we do recommend using the product within one year of opening it to guarantee freshness and efficacy. What is LA’s Totally Awesome All Purpose Cleaner ® made from? LA’s Totally Awesome All Purpose Cleaner ® is a blend of water, surfactant (surface-active) agents, color and scent. Surfactant agents lift grease and oil up off of the surface. LA’s Totally Awesome All Purpose Cleaner ® is a safe, naturally gentle soap, specially formulated for cleaning a variety of surfaces like floors, furniture, and other household surfaces. And it leaves your home smelling fresh and clean. LA’s Totally Awesome All Purpose Cleaner ® contains no harsh detergents, ammonia, or bleach. Why aren't the ingredients listed on the label? LA’s Totally Awesome All Purpose Cleaner ® is non-toxic. Therefore, the listing of ingredients on the label is not required by law.", 'h_question': "Why do surfactant agents play an important role in LA' s Totally Awesome All-Purpose Cleaner?", 'title': "LA's Totally Awesome Products - FAQs", 'end_char': 4697, 'docid': 'msmarco_v2.1_doc_00_116164#8_161107'}, references=None, vector={}, collection='Mini_data_segment_hyde')],
# ...
#    Object(uuid=_WeaviateUUIDInt('5a754367-4ca9-4cc5-bee1-d16a1fb7e93c'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.6643286347389221, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': 'Everything You Need To Know About Construction\nEverything You Need To Know About Construction\n4 Things To Know About Self-Contained Septic Systems As Waste Treatment Alternatives\n1. Reduce Groundwater Contamination\n2. Conserve Water With Recycling Of Treated Water\n3. Simple To Maintain And Access Your System For Maintenance\n4. An Ideal Solution For Homes With Sensitive Septic Requirements\n', 'start_char': 1134, 'end_char': 2056, 'segment': 'This means that these systems to not have the problem of contaminating groundwater supplies, which makes them ideal for homes with wells that are used for the main water service. 2. Conserve Water With Recycling Of Treated Water\nYou can also conserve water with a self-contained septic system. Since these systems are like a miniature sewage treatment plant, the wastewater can often be used for various needs. It can be filtered and use to flush toilets and as irrigation around your home. This can also help your home to be more energy efficient. 3. Simple To Maintain And Access Your System For Maintenance\nAnother benefit of a self-contained system is that it is easily accessible. Since it is not buried like a conventional system, you will be able to easily access your system. This makes it easier to do maintenance and repairs to your system, as well as catch problems with your system before they get out of hand.', 'h_question': 'How can recycling treated water contribute to energy efficiency in homes?', 'title': '4 Things To Know About Self-Contained Septic Systems As Waste Treatment Alternatives - Everything You Need To Know About Construction', 'url': 'http://01construction.com/2015/04/21/4-things-to-know-about-self-contained-septic-systems-as-waste-treatment-alternatives/', 'docid': 'msmarco_v2.1_doc_00_224481#2_330389'}, references=None, vector={}, collection='Mini_data_segment_hyde')]},
#  'time in time zones in us': {'nonhyde': [Object(uuid=_WeaviateUUIDInt('1d72f692-e173-4724-bd4b-ff1d9c0262ce'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.8700140714645386, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 2501, 'url': 'http://001yourtranslationservice.com/kenax/Translators/Resources/TimeZones.htm', 'segment': 'Muscat; Tblisi; Volgograd; Kabul\n+4:00\n13:00 – 21:00\nZP5\nChesapeake Bay\n+5:00\n14:00 – 22:00\nZP6\nChesapeake Bay\n+6:00\n15:00 – 23:00\nWAST\nWest Australian Standard\n+7:00\n16:00 – 24:00\nCCT\nChina Coast, Russia Zone 7, Hong Kong, Peking\n+8:00\n17:00 – 01:00\nJST\nJapan Standard, Russia Zone 8\n+9:00\n18:00 – 02:00\nGST\nGuam Standard, Russia Zone 9\n+10:00\n19:00 – 03:00\n\n\n+11:00\n20:00 – 04:00\nIDLE\nInternational Date Line East: Wellington, New\nZealand\n+12:00\n21:00 – 05:00\nNZST\nNew Zealand Standard: Fiji\n+12:00\n21:00 – 05:00\nNZT\nNew Zealand: Marshall\nIslands\n+12:00\n21:00 – 05:00\nTherefore, if something is due at 16:00 (4:00pm) GMT time, and you are located in Volgograd Russia on ZP4 time, you would have to deliver your work by 20:00 (8:00pm) your time (add four hours to the due date, according to the third column in the table above). Share|\nWhat are Time Zones? Well, we could ask what is time? To explain this, let us go\nto the beginning of what we can define as time.', 'h_question': 'Can you explain why some countries have multiple time zones while others have only one?', 'title': '', 'end_char': 3466, 'docid': 'msmarco_v2.1_doc_00_39686#8_81164'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('9c9d0460-119f-4b88-a185-86342f3e00b5'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7592521905899048, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 2989, 'url': 'http://001yourtranslationservice.com/kenax/Translators/Resources/TimeZones.htm', 'segment': 'Fiji\n+12:00\n21:00 – 05:00\nNZT\nNew Zealand: Marshall\nIslands\n+12:00\n21:00 – 05:00\nTherefore, if something is due at 16:00 (4:00pm) GMT time, and you are located in Volgograd Russia on ZP4 time, you would have to deliver your work by 20:00 (8:00pm) your time (add four hours to the due date, according to the third column in the table above). Share|\nWhat are Time Zones? Well, we could ask what is time? To explain this, let us go\nto the beginning of what we can define as time. Let us presume that, before the big bang, there was only\nenergy, and no time. We can say that God was this energy. And "then" he decided\nto make things, so he converted this energy into massand hence was created the big bang, which was an explosion of the energy force turning\ninto matter. Exploding outwards in all directions, and creating the universe, or many\nuniverses, and therefore dimensions, where time is considered the fourth dimension. Everything is relative.', 'h_question': 'In what ways do the concepts of relativity and dimensions mentioned in the text influence our understanding of time zones and their practical applications?', 'title': '', 'end_char': 3937, 'docid': 'msmarco_v2.1_doc_00_39686#9_82451'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('0f21a067-fa09-41ee-9064-018a76aadb7c'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7125370502471924, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 1664, 'url': 'http://001yourtranslationservice.com/kenax/Translators/Resources/TimeZones.htm', 'segment': 'New York, NY, USA\n-5:00\n04:00 – 12:00\nCST\nCentral Standard: Mexico\nCity, Mexico; Saskatchewan, Canada\n-6:00\n03:00 – 11:00\nMST\nMountain\nStandard\n-7:00\n02:00 – 10:00\nPST\nPacific Standard: Los Angeles, CA, USA\n-8:00\n01:00 – 09:00\nYST\nYukon\nStandard\n-9:00\n24:00 – 08:00\nAHST, CAT, HST, EAST\nAlaska-Hawaii Standard; Central Alaska; Hawaii Standard; 09: East Australian Standard\n-10:00\n23:00 – 07:00\nNT\nNome\n-11:00\n22:00 – 06:00\nIDLW\nInternational Date Line West\n-12:00\n21:00 – 05:00\nCET\nCentral European: Paris, France\n+1:00 \n10:00 – 18:00\nEET\nEastern European, Russia Zone 1: Athens,\nGreece;', 'h_question': 'Which city in Mexico has a time zone of -5:00, with hours from 04:00 to 12:00?', 'title': '', 'end_char': 2250, 'docid': 'msmarco_v2.1_doc_00_39686#4_78208'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('de3a37e3-a0e3-4d9c-a526-6e4e61ee0836'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.6859027743339539, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 1522, 'end_char': 1990, 'segment': 'Georgetown, Guyana\n-3:00\n06:00 – 14:00\nAST\nAtlantic\nStandard: Caracas; La Paz\n-4:00 \n05:00 – 13:00\nEST\nEastern Standard: Bogota; Lima, Peru; New York, NY, USA\n-5:00\n04:00 – 12:00\nCST\nCentral Standard: Mexico\nCity, Mexico; Saskatchewan, Canada\n-6:00\n03:00 – 11:00\nMST\nMountain\nStandard\n-7:00\n02:00 – 10:00\nPST\nPacific Standard: Los Angeles, CA, USA\n-8:00\n01:00 – 09:00\nYST\nYukon\nStandard\n-9:00\n24:00 – 08:00\nAHST, CAT, HST, EAST\nAlaska-Hawaii Standard; Central Alaska;', 'h_question': 'Which time zone corresponds to the UTC offsets -9:00 and 24:00 – 08:00?', 'title': '', 'url': 'http://001yourtranslationservice.com/kenax/Translators/Resources/TimeZones.htm', 'docid': 'msmarco_v2.1_doc_00_39686#3_77454'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('01d964db-243f-40d5-b088-1a3ba96fe234'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.6631371974945068, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 2379, 'url': 'http://001yourtranslationservice.com/kenax/Translators/Resources/TimeZones.htm', 'segment': 'Nairobi,\nKenya; Riyadh, Saudi Arabia; Moscow, Russia; Tehran, Iran\n+3:00\n12:00 – 20:00\nZP4\nRussia Zone 3: Abu Dhabi, UAE; Muscat; Tblisi; Volgograd; Kabul\n+4:00\n13:00 – 21:00\nZP5\nChesapeake Bay\n+5:00\n14:00 – 22:00\nZP6\nChesapeake Bay\n+6:00\n15:00 – 23:00\nWAST\nWest Australian Standard\n+7:00\n16:00 – 24:00\nCCT\nChina Coast, Russia Zone 7, Hong Kong, Peking\n+8:00\n17:00 – 01:00\nJST\nJapan Standard, Russia Zone 8\n+9:00\n18:00 – 02:00\nGST\nGuam Standard, Russia Zone 9\n+10:00\n19:00 – 03:00\n\n\n+11:00\n20:00 – 04:00\nIDLE\nInternational Date Line East: Wellington, New\nZealand\n+12:00\n21:00 – 05:00\nNZST\nNew Zealand Standard:', 'h_question': 'What is the purpose of the list of cities and time zones?', 'title': '', 'end_char': 2989, 'docid': 'msmarco_v2.1_doc_00_39686#7_80242'}, references=None, vector={}, collection='Mini_data_segment_hyde')],
#   'hyde': [Object(uuid=_WeaviateUUIDInt('56e332b8-87fc-4641-8ed2-11b490a33477'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7857255339622498, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 1664, 'url': 'http://001yourtranslationservice.com/kenax/Translators/Resources/TimeZones.htm', 'segment': 'New York, NY, USA\n-5:00\n04:00 – 12:00\nCST\nCentral Standard: Mexico\nCity, Mexico; Saskatchewan, Canada\n-6:00\n03:00 – 11:00\nMST\nMountain\nStandard\n-7:00\n02:00 – 10:00\nPST\nPacific Standard: Los Angeles, CA, USA\n-8:00\n01:00 – 09:00\nYST\nYukon\nStandard\n-9:00\n24:00 – 08:00\nAHST, CAT, HST, EAST\nAlaska-Hawaii Standard; Central Alaska; Hawaii Standard; 09: East Australian Standard\n-10:00\n23:00 – 07:00\nNT\nNome\n-11:00\n22:00 – 06:00\nIDLW\nInternational Date Line West\n-12:00\n21:00 – 05:00\nCET\nCentral European: Paris, France\n+1:00 \n10:00 – 18:00\nEET\nEastern European, Russia Zone 1: Athens,\nGreece;', 'h_question': 'Which city in Canada has a time zone of -6:00, with hours from 03:00 to 11:00?', 'title': '', 'end_char': 2250, 'docid': 'msmarco_v2.1_doc_00_39686#4_78208'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('de3a37e3-a0e3-4d9c-a526-6e4e61ee0836'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7778449058532715, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 1522, 'url': 'http://001yourtranslationservice.com/kenax/Translators/Resources/TimeZones.htm', 'segment': 'Georgetown, Guyana\n-3:00\n06:00 – 14:00\nAST\nAtlantic\nStandard: Caracas; La Paz\n-4:00 \n05:00 – 13:00\nEST\nEastern Standard: Bogota; Lima, Peru; New York, NY, USA\n-5:00\n04:00 – 12:00\nCST\nCentral Standard: Mexico\nCity, Mexico; Saskatchewan, Canada\n-6:00\n03:00 – 11:00\nMST\nMountain\nStandard\n-7:00\n02:00 – 10:00\nPST\nPacific Standard: Los Angeles, CA, USA\n-8:00\n01:00 – 09:00\nYST\nYukon\nStandard\n-9:00\n24:00 – 08:00\nAHST, CAT, HST, EAST\nAlaska-Hawaii Standard; Central Alaska;', 'h_question': 'Which time zone corresponds to the UTC offsets -9:00 and 24:00 – 08:00?', 'title': '', 'end_char': 1990, 'docid': 'msmarco_v2.1_doc_00_39686#3_77454'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('1cc70d95-027d-4b12-9757-cbe945e1729b'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7641346454620361, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 2501, 'url': 'http://001yourtranslationservice.com/kenax/Translators/Resources/TimeZones.htm', 'segment': 'Muscat; Tblisi; Volgograd; Kabul\n+4:00\n13:00 – 21:00\nZP5\nChesapeake Bay\n+5:00\n14:00 – 22:00\nZP6\nChesapeake Bay\n+6:00\n15:00 – 23:00\nWAST\nWest Australian Standard\n+7:00\n16:00 – 24:00\nCCT\nChina Coast, Russia Zone 7, Hong Kong, Peking\n+8:00\n17:00 – 01:00\nJST\nJapan Standard, Russia Zone 8\n+9:00\n18:00 – 02:00\nGST\nGuam Standard, Russia Zone 9\n+10:00\n19:00 – 03:00\n\n\n+11:00\n20:00 – 04:00\nIDLE\nInternational Date Line East: Wellington, New\nZealand\n+12:00\n21:00 – 05:00\nNZST\nNew Zealand Standard: Fiji\n+12:00\n21:00 – 05:00\nNZT\nNew Zealand: Marshall\nIslands\n+12:00\n21:00 – 05:00\nTherefore, if something is due at 16:00 (4:00pm) GMT time, and you are located in Volgograd Russia on ZP4 time, you would have to deliver your work by 20:00 (8:00pm) your time (add four hours to the due date, according to the third column in the table above). Share|\nWhat are Time Zones? Well, we could ask what is time? To explain this, let us go\nto the beginning of what we can define as time.', 'h_question': 'How do you adjust your clock when traveling across different time zones?', 'title': '', 'end_char': 3466, 'docid': 'msmarco_v2.1_doc_00_39686#8_81164'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('71c5d253-fc3d-4dbb-bb25-e281d5ef70f7'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7384915351867676, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 2379, 'end_char': 2989, 'segment': 'Nairobi,\nKenya; Riyadh, Saudi Arabia; Moscow, Russia; Tehran, Iran\n+3:00\n12:00 – 20:00\nZP4\nRussia Zone 3: Abu Dhabi, UAE; Muscat; Tblisi; Volgograd; Kabul\n+4:00\n13:00 – 21:00\nZP5\nChesapeake Bay\n+5:00\n14:00 – 22:00\nZP6\nChesapeake Bay\n+6:00\n15:00 – 23:00\nWAST\nWest Australian Standard\n+7:00\n16:00 – 24:00\nCCT\nChina Coast, Russia Zone 7, Hong Kong, Peking\n+8:00\n17:00 – 01:00\nJST\nJapan Standard, Russia Zone 8\n+9:00\n18:00 – 02:00\nGST\nGuam Standard, Russia Zone 9\n+10:00\n19:00 – 03:00\n\n\n+11:00\n20:00 – 04:00\nIDLE\nInternational Date Line East: Wellington, New\nZealand\n+12:00\n21:00 – 05:00\nNZST\nNew Zealand Standard:', 'h_question': 'Which city has a +3:00 time zone?', 'title': '', 'url': 'http://001yourtranslationservice.com/kenax/Translators/Resources/TimeZones.htm', 'docid': 'msmarco_v2.1_doc_00_39686#7_80242'}, references=None, vector={}, collection='Mini_data_segment_hyde'),
#    Object(uuid=_WeaviateUUIDInt('626dd932-ad1c-446b-9de8-1de29a2840e0'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=0.7376053333282471, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'headings': '\n', 'start_char': 2251, 'url': 'http://001yourtranslationservice.com/kenax/Translators/Resources/TimeZones.htm', 'segment': 'Helsinki, Finland; Istanbul, Turkey; Jerusalem, Israel; Harare, Zimbabwe\n+2:00\n11:00 – 19:00\nBT\nBaghdad, Russia Zone 2: Kuwait; Nairobi,\nKenya; Riyadh, Saudi Arabia; Moscow, Russia; Tehran, Iran\n+3:00\n12:00 – 20:00\nZP4\nRussia Zone 3: Abu Dhabi, UAE;', 'h_question': "What is the time range for each hour in Helsinki's time zone?", 'title': '', 'end_char': 2500, 'docid': 'msmarco_v2.1_doc_00_39686#6_79754'}, references=None, vector={}, collection='Mini_data_segment_hyde')]}}

# %% [markdown]
# ## Similarity Metric Comparison

# %%
#this gives a comparison between retrieved certainty scores(cosine similarity)
def compare_certainties(eval_dic):
    total_top_c_diff = 0

    nonhyde_total_certainty = 0
    hyde_total_certainty = 0

    len_eval = len(eval_dic.keys())

    for topic in eval_dic.keys():
        nonhyde_segments = eval_dic[topic]["nonhyde"]
        hyde_segments = eval_dic[topic]["hyde"]
        
        nonhyde_segments_top_c = nonhyde_segments[0].metadata.certainty
        hyde_segments_top_c = hyde_segments[0].metadata.certainty

        top_c_diff = hyde_segments_top_c - nonhyde_segments_top_c 
        
        
        for i in range(4):
            nonhyde_total_certainty += nonhyde_segments[i].metadata.certainty
            hyde_total_certainty += hyde_segments[i].metadata.certainty

        total_top_c_diff += top_c_diff

    total_certainty_diff = hyde_total_certainty - nonhyde_total_certainty
    avg_certainty_diff = total_certainty_diff/len_eval
    avg_top_certainty_diff = total_top_c_diff/len_eval


    print("Difference between total certainties: ", (total_certainty_diff), " and the avg. certainty change per question: ", (avg_certainty_diff) )
    print("Difference between top certainties: ", (total_top_c_diff), " and the avg. difference in top certainties: ", (avg_top_certainty_diff))

# %%
compare_certainties(eval_dic)
# Out:
# Difference between total certainties:  -0.1685647964477539  and the avg. certainty change per question:  -0.018729421827528212
# Difference between top certainties:  0.03347349166870117  and the avg. difference in top certainties:  0.003719276852077908

# %%
for topic in eval_dic.keys():

    nonhyde_segments = eval_dic[topic]["nonhyde"]
    hyde_segments = eval_dic[topic]["hyde"]



    print(topic)
    print()
    for segment_i in range(4):
        print("Non-hyde certainty: ", nonhyde_segments[segment_i].metadata.certainty," Hyde certainty: ", hyde_segments[segment_i].metadata.certainty )
        print()
    print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# what is function of registry
#
# Non-hyde certainty:  0.7431946396827698  Hyde certainty:  0.8076457977294922
#
# Non-hyde certainty:  0.6820136308670044  Hyde certainty:  0.7454531788825989
#
# Non-hyde certainty:  0.6575680375099182  Hyde certainty:  0.6477391719818115
#
# Non-hyde certainty:  0.640792727470398  Hyde certainty:  0.6451333165168762
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# what is the fastest car in the?
#
# Non-hyde certainty:  0.826582670211792  Hyde certainty:  0.7787390351295471
#
# Non-hyde certainty:  0.784464955329895  Hyde certainty:  0.7160167694091797
#
# Non-hyde certainty:  0.782470166683197  Hyde certainty:  0.7117319107055664
#
# Non-hyde certainty:  0.7397179007530212  Hyde certainty:  0.6897644400596619
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# definition of shelf life
#
# Non-hyde certainty:  0.7076284885406494  Hyde certainty:  0.8197730779647827
#
# Non-hyde certainty:  0.7073252201080322  Hyde certainty:  0.6377778053283691
#
# Non-hyde certainty:  0.6150607466697693  Hyde certainty:  0.5930086970329285
#
# Non-hyde certainty:  0.5876338481903076  Hyde certainty:  0.5911209583282471
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# what were the egyptian political and religious leaders called?
#
# Non-hyde certainty:  0.8144927620887756  Hyde certainty:  0.7451663017272949
#
# Non-hyde certainty:  0.7888434529304504  Hyde certainty:  0.7268738746643066
#
# Non-hyde certainty:  0.7736910581588745  Hyde certainty:  0.7136921882629395
#
# Non-hyde certainty:  0.6905502080917358  Hyde certainty:  0.7020905017852783
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# effective way to clean tile floors
#
# Non-hyde certainty:  0.7748470306396484  Hyde certainty:  0.8147393465042114
#
# Non-hyde certainty:  0.7081442475318909  Hyde certainty:  0.765795111656189
#
# Non-hyde certainty:  0.707247257232666  Hyde certainty:  0.7380837202072144
#
# Non-hyde certainty:  0.7022380828857422  Hyde certainty:  0.7367231845855713
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# where did urdu language come from
#
# Non-hyde certainty:  0.8226515054702759  Hyde certainty:  0.7965943813323975
#
# Non-hyde certainty:  0.7864192724227905  Hyde certainty:  0.7468658089637756
#
# Non-hyde certainty:  0.7813200354576111  Hyde certainty:  0.7242878079414368
#
# Non-hyde certainty:  0.7620447278022766  Hyde certainty:  0.7233890295028687
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# who developed the iq test that is most widely used today?
#
# Non-hyde certainty:  0.8171573281288147  Hyde certainty:  0.7887106537818909
#
# Non-hyde certainty:  0.7614806890487671  Hyde certainty:  0.7537894248962402
#
# Non-hyde certainty:  0.7588388919830322  Hyde certainty:  0.7534711956977844
#
# Non-hyde certainty:  0.7346089482307434  Hyde certainty:  0.740383505821228
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# what plastics are recyclable in el paso tx
#
# Non-hyde certainty:  0.7642024755477905  Hyde certainty:  0.8371503353118896
#
# Non-hyde certainty:  0.7258530855178833  Hyde certainty:  0.7725502252578735
#
# Non-hyde certainty:  0.6987059116363525  Hyde certainty:  0.6778191328048706
#
# Non-hyde certainty:  0.6754648685455322  Hyde certainty:  0.6741196513175964
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# time in time zones in us
#
# Non-hyde certainty:  0.8700140714645386  Hyde certainty:  0.7857255339622498
#
# Non-hyde certainty:  0.7592521905899048  Hyde certainty:  0.7778449058532715
#
# Non-hyde certainty:  0.7125370502471924  Hyde certainty:  0.7641346454620361
#
# Non-hyde certainty:  0.6859027743339539  Hyde certainty:  0.7384915351867676
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# ## Human evaluation

# %%
#method 1 is nonhyde method 2 is hyde kept anonymous for eval purposes
exp_text = ""
for topic in eval_dic.keys():

    exp_text += "The query was: " + topic + " and the returned segments are: \n"

    nonhyde_segments = eval_dic[topic]["nonhyde"]
    hyde_segments = eval_dic[topic]["hyde"]

    
    nonhyde_text = "For method 1: \n"
    hyde_text = "For method 2: \n"
    for i in range(4):
        nonhyde_text += "SEGMENT NO "+ str(i+1) + ": \n " + nonhyde_segments[i].properties["segment"] + "\n"
        hyde_text += "SEGMENT NO "+ str(i+1) + ": \n " + hyde_segments[i].properties["segment"]+ "\n"
        
    exp_text += nonhyde_text + "\n \n"
    exp_text += hyde_text + "\n xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx \n"

with open("eval_text.txt", "w") as text_file:
    text_file.write(exp_text)
# Out:
# The query was: what is function of registry and the returned segments are:
# For method 1:
# SEGMENT NO 1:
#  Open 00000 file article translations
# For more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating
# systems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System
# Registry, review some possible attacks to it and ways to avoid them...
# Folders, files and paths- Files are the entries or information stored on your
# computer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by
# Microsoft with their products including system files for their series of operating systems...
# What are file extensions? - File extensions are unnoticed yet are very crucial parts of
# the computer world. But many are still unaware of the basic foundation and principles behind the remarkable wonders of computers...
# © Copyright 2021 extensionfile.net Privacy Policy. Terms of Service
# SEGMENT NO 2:
#  Install the application you found and check if it can open 00000 file
# Rate 00000 filepage: 54321
# 4/5based on 27ratings
# Populating this website with information and maintaining it is an ongoing process. We always welcome feedback and questions that can be submitted by visiting Contact Us page. However since there are many users visiting this website and because our team is quite small we may not be able to follow up personally on every request. Thank you for your understanding. Open 00000 file article translations
# For more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating
# systems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System
# Registry, review some possible attacks to it and ways to avoid them...
# Folders, files and paths- Files are the entries or information stored on your
# computer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by
# Microsoft with their products including system files for their series of operating systems...
# What are file extensions? -
# SEGMENT NO 3:
#  Comprehend level. Click on the activity hyperlink for a list of procedures to follow for using the activity. Activity Example or Non-Example? Purpose and Description
# The purpose of this activity is to allow students to practice classifying defined concepts. Students are given instances that represent Examples and Non-Examples. They must correctly name the defined concept described. Format
# Class
# Preparation and Materials Required
# __________________________________________________________________________________________________________
# List of Examples and Non-Examples for the defined concepts
# Instructor presentation materials
# Example and Non-Example Creation
# The purpose of this activity is to allow students to practice comprehending the characteristics of the defined concepts by creating Examples and Non-Examples of the defined concepts. Format
# Individual
# Pairs
# Small group
# Preparation and Materials Required
# Handouts of a list of defined concepts
# Student presentation materials
# __________________________________________________________________________________________________________
# Narrative Generation from Examples and Non-Examples
# The purpose of this activity is to allow students to practice and test their understanding of the characteristics of the defined concepts by creating narratives from a list of Examples and Non-Examples that summarize the lesson content. Format
# Individual
# Pairs
# Small group
# Preparation and Materials Required
# Handouts of Examples and Non-Examples of the defined concepts
# _________________________________________________________________________________________________________
# Procedures for Example or Non-Example? 1.
# SEGMENT NO 4:
#  What is 00J File? File extensions help computers locate correct application for specific files. Operating systems will not look into the content of the files to be opened, but instead, it will immediately locate the file extension of the file and locate for associated application that can open 00J files. This helps the computer to organize its functions and work much faster. Most operating systems (Windows) require the use of file extensions, but others do not (Unix). These file extensions are also beneficial for us. By simply looking at the filename, we can determine what type of information is stored to that and what applications can open these files. Have you noticed that when your computer acquires an unknown file, it will ask your permission to look for associated program to open it or look for these programs over the Internet? Yes! These file extensions make the work of the computer easy.
#
#
# For method 2:
# SEGMENT NO 1:
#  Open 00000 file article translations
# For more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating
# systems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System
# Registry, review some possible attacks to it and ways to avoid them...
# Folders, files and paths- Files are the entries or information stored on your
# computer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by
# Microsoft with their products including system files for their series of operating systems...
# What are file extensions? - File extensions are unnoticed yet are very crucial parts of
# the computer world. But many are still unaware of the basic foundation and principles behind the remarkable wonders of computers...
# © Copyright 2021 extensionfile.net Privacy Policy. Terms of Service
# SEGMENT NO 2:
#  Install the application you found and check if it can open 00000 file
# Rate 00000 filepage: 54321
# 4/5based on 27ratings
# Populating this website with information and maintaining it is an ongoing process. We always welcome feedback and questions that can be submitted by visiting Contact Us page. However since there are many users visiting this website and because our team is quite small we may not be able to follow up personally on every request. Thank you for your understanding. Open 00000 file article translations
# For more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating
# systems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System
# Registry, review some possible attacks to it and ways to avoid them...
# Folders, files and paths- Files are the entries or information stored on your
# computer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by
# Microsoft with their products including system files for their series of operating systems...
# What are file extensions? -
# SEGMENT NO 3:
#  Cameras are required to be on during SEL (social-emotional learning) and Live instruction (20-25 mins). If a teacher is unable to see or no responses are given when called, that will lead to the student being marked absent. Parents and families, please remember to check your parent portal to view your child’s attendance and grades. Online Registration System
# Since May 2020, Clayton County Public Schools (CCPS) has been offering anOnlineRegistration
# (OLR) process for students who areregisteringfor new/returning students who arenot currently enrolled with CCPS for the 2020-2021 school year. For more information regarding 2020-2021 Online Registration, please view the video at http://youtu.be/cct5TjGH7Twor visit the CCPS website (http://www.clayton.k12.ga.us). Registration Central Page
# https://www.clayton.k12.ga.us/cms/One.aspx?portalId=54515&pageId=237811
# CCPS Withdrawal Request Google Form
# For more information about counseling related topics, please visit the counseling page. Online Textbooks and Digital Resources
# We are working to make sure that all students and parents have access to textbooks and resources. As info, there are two documents you can reference. The first is the CCPS flyer about available resources. The second provides resources available for our students and parents at RHS.
# SEGMENT NO 4:
#  Explain that the purpose of this activity is to practice comprehending the characteristics of the defined concepts presented by classifying Examples and Non-Examples of the defined concepts. 2. Present a new Example or Non-Example (that has not been previously presented to students) of the defined concept from the list. 3. Have students determine if it is an Example or Non-Example and explain what characteristics make it an Example or Non-Example. 4. Provide feedback for the answer. 5. Repeat steps 2-4 until the students have correctly identified every defined concept from the list. 6.
#
#  xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
# The query was: what is function of registry and the returned segments are:
# For method 1:
# SEGMENT NO 1:
#  Open 00000 file article translations
# For more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating
# systems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System
# Registry, review some possible attacks to it and ways to avoid them...
# Folders, files and paths- Files are the entries or information stored on your
# computer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by
# Microsoft with their products including system files for their series of operating systems...
# What are file extensions? - File extensions are unnoticed yet are very crucial parts of
# the computer world. But many are still unaware of the basic foundation and principles behind the remarkable wonders of computers...
# © Copyright 2021 extensionfile.net Privacy Policy. Terms of Service
# SEGMENT NO 2:
#  Install the application you found and check if it can open 00000 file
# Rate 00000 filepage: 54321
# 4/5based on 27ratings
# Populating this website with information and maintaining it is an ongoing process. We always welcome feedback and questions that can be submitted by visiting Contact Us page. However since there are many users visiting this website and because our team is quite small we may not be able to follow up personally on every request. Thank you for your understanding. Open 00000 file article translations
# For more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating
# systems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System
# Registry, review some possible attacks to it and ways to avoid them...
# Folders, files and paths- Files are the entries or information stored on your
# computer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by
# Microsoft with their products including system files for their series of operating systems...
# What are file extensions? -
# SEGMENT NO 3:
#  Comprehend level. Click on the activity hyperlink for a list of procedures to follow for using the activity. Activity Example or Non-Example? Purpose and Description
# The purpose of this activity is to allow students to practice classifying defined concepts. Students are given instances that represent Examples and Non-Examples. They must correctly name the defined concept described. Format
# Class
# Preparation and Materials Required
# __________________________________________________________________________________________________________
# List of Examples and Non-Examples for the defined concepts
# Instructor presentation materials
# Example and Non-Example Creation
# The purpose of this activity is to allow students to practice comprehending the characteristics of the defined concepts by creating Examples and Non-Examples of the defined concepts. Format
# Individual
# Pairs
# Small group
# Preparation and Materials Required
# Handouts of a list of defined concepts
# Student presentation materials
# __________________________________________________________________________________________________________
# Narrative Generation from Examples and Non-Examples
# The purpose of this activity is to allow students to practice and test their understanding of the characteristics of the defined concepts by creating narratives from a list of Examples and Non-Examples that summarize the lesson content. Format
# Individual
# Pairs
# Small group
# Preparation and Materials Required
# Handouts of Examples and Non-Examples of the defined concepts
# _________________________________________________________________________________________________________
# Procedures for Example or Non-Example? 1.
# SEGMENT NO 4:
#  What is 00J File? File extensions help computers locate correct application for specific files. Operating systems will not look into the content of the files to be opened, but instead, it will immediately locate the file extension of the file and locate for associated application that can open 00J files. This helps the computer to organize its functions and work much faster. Most operating systems (Windows) require the use of file extensions, but others do not (Unix). These file extensions are also beneficial for us. By simply looking at the filename, we can determine what type of information is stored to that and what applications can open these files. Have you noticed that when your computer acquires an unknown file, it will ask your permission to look for associated program to open it or look for these programs over the Internet? Yes! These file extensions make the work of the computer easy.
#
#
# For method 2:
# SEGMENT NO 1:
#  Open 00000 file article translations
# For more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating
# systems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System
# Registry, review some possible attacks to it and ways to avoid them...
# Folders, files and paths- Files are the entries or information stored on your
# computer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by
# Microsoft with their products including system files for their series of operating systems...
# What are file extensions? - File extensions are unnoticed yet are very crucial parts of
# the computer world. But many are still unaware of the basic foundation and principles behind the remarkable wonders of computers...
# © Copyright 2021 extensionfile.net Privacy Policy. Terms of Service
# SEGMENT NO 2:
#  Install the application you found and check if it can open 00000 file
# Rate 00000 filepage: 54321
# 4/5based on 27ratings
# Populating this website with information and maintaining it is an ongoing process. We always welcome feedback and questions that can be submitted by visiting Contact Us page. However since there are many users visiting this website and because our team is quite small we may not be able to follow up personally on every request. Thank you for your understanding. Open 00000 file article translations
# For more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating
# systems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System
# Registry, review some possible attacks to it and ways to avoid them...
# Folders, files and paths- Files are the entries or information stored on your
# computer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by
# Microsoft with their products including system files for their series of operating systems...
# What are file extensions? -
# SEGMENT NO 3:
#  Cameras are required to be on during SEL (social-emotional learning) and Live instruction (20-25 mins). If a teacher is unable to see or no responses are given when called, that will lead to the student being marked absent. Parents and families, please remember to check your parent portal to view your child’s attendance and grades. Online Registration System
# Since May 2020, Clayton County Public Schools (CCPS) has been offering anOnlineRegistration
# (OLR) process for students who areregisteringfor new/returning students who arenot currently enrolled with CCPS for the 2020-2021 school year. For more information regarding 2020-2021 Online Registration, please view the video at http://youtu.be/cct5TjGH7Twor visit the CCPS website (http://www.clayton.k12.ga.us). Registration Central Page
# https://www.clayton.k12.ga.us/cms/One.aspx?portalId=54515&pageId=237811
# CCPS Withdrawal Request Google Form
# For more information about counseling related topics, please visit the counseling page. Online Textbooks and Digital Resources
# We are working to make sure that all students and parents have access to textbooks and resources. As info, there are two documents you can reference. The first is the CCPS flyer about available resources. The second provides resources available for our students and parents at RHS.
# SEGMENT NO 4:
#  Explain that the purpose of this activity is to practice comprehending the characteristics of the defined concepts presented by classifying Examples and Non-Examples of the defined concepts. 2. Present a new Example or Non-Example (that has not been previously presented to students) of the defined concept from the list. 3. Have students determine if it is an Example or Non-Example and explain what characteristics make it an Example or Non-Example. 4. Provide feedback for the answer. 5. Repeat steps 2-4 until the students have correctly identified every defined concept from the list. 6.
#
#  xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# The query was: what is the fastest car in the? and the returned segments are:
# For method 1:
# SEGMENT NO 1:
#  But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version. But both measure the performance of a car. A lot goes into increasing 0-60 times in performance vehicles. As a normal rule of thumb, performance cars are considered those with 0-60 time of under 6 seconds, while Exotic cars will do 0-60 in 3 to 4 seconds. However, in most cases, a car isn’t simply “stuck with” the acceleration number with which it was born. Engineers and designers work tirelessly to provide better and better numbers with each progressive model of performance and exotic cars.
# SEGMENT NO 2:
#  But both measure the performance of a car. A lot goes into increasing 0-60 times in performance vehicles. As a normal rule of thumb, performance cars are considered those with 0-60 time of under 6 seconds, while Exotic cars will do 0-60 in 3 to 4 seconds. However, in most cases, a car isn’t simply “stuck with” the acceleration number with which it was born. Engineers and designers work tirelessly to provide better and better numbers with each progressive model of performance and exotic cars. But, even the back yard mechanic or muscle car enthusiast can determine the 0-60 times of their cars and make moves to improve them. The testing of acceleration is usually done on a closed course away from people other than the team that may be working on the specific car. This limits putting anyone in danger who is not part of the test or the ongoing project. Testers can use something as simple as a stop watch and the vehicle’s speedometer. This is probably good enough for the typical muscle car enthusiast who is just looking for an estimate of how much power his latest improvements will give him.
# SEGMENT NO 3:
#  0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews
# 0-60 Times
# There are many ways to measure the power a vehicle has – top speed, horsepower, foot-pounds of torque. Those are all important, but the most asked question is, “What’s the 0-60 time?” This is nothing more than a measure of how quickly a vehicle can reach the 60 mile per hour mark. It is a measure of acceleration of a vehicle. 0-60 times differ a great deal depending on the amount of power a motor puts out, of course. But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version.
# SEGMENT NO 4:
#  Instead, some believe the measure should include a range of times rather than one finite mark to which all cars of any particular model should be held. For instance, they believe a BMW M3 should have a listed time of 3.9 – 4.2 seconds and a Corvette Z06 should have a range from 3.6 to 4.0. These people believe that a range of numbers better represents what an owner can honestly expect to see when he or she takes delivery of a new vehicle. This contingent of car enthusiasts and engineers believes that there is no way for either the time to 60 mph or even a quarter mile time to be completely accurate, as there are simply too many variables that come into play. No matter if you are a 0 – 60 purist, or you believe that it is an inexact science, you can be sure that the measure itself will not be going away any time soon. It is still one of the biggest touted numbers for vehicles, and easier for people to relate to than horsepower and torque.
#
#
# For method 2:
# SEGMENT NO 1:
#  But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version. But both measure the performance of a car. A lot goes into increasing 0-60 times in performance vehicles. As a normal rule of thumb, performance cars are considered those with 0-60 time of under 6 seconds, while Exotic cars will do 0-60 in 3 to 4 seconds. However, in most cases, a car isn’t simply “stuck with” the acceleration number with which it was born. Engineers and designers work tirelessly to provide better and better numbers with each progressive model of performance and exotic cars.
# SEGMENT NO 2:
#  0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews
# 0-60 Times
# There are many ways to measure the power a vehicle has – top speed, horsepower, foot-pounds of torque. Those are all important, but the most asked question is, “What’s the 0-60 time?” This is nothing more than a measure of how quickly a vehicle can reach the 60 mile per hour mark. It is a measure of acceleration of a vehicle. 0-60 times differ a great deal depending on the amount of power a motor puts out, of course. But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version.
# SEGMENT NO 3:
#  For engineers testing a new exotic sports car, though, a simple estimate is not accurate enough. They want hard and fast 0-60 times, and they use much more highly-technical equipment to get their numbers. With the 0-60 figure being so important in automobile sales, they do everything possible to ensure their numbers are incredibly accurate. In professional testing situations, highly technical and accurate measuring devices are hooked to computers as the test is performed. The test is run in two different directions, to eliminate any influence of wind, an unseen downhill grade or any differences in traction. The average of these two times will be the recorded 0-60 time for the car. Doppler radar guns are used to ensure the tester is recording exact 0 -60 times. This leaves the driver to focus solely on running through the gears as precisely as possible and simply driving in a straight line. This allow for a more accurate measure, as does running the test first in one direction and then in the exact opposite direction. Some still feel, however, that listing one 0 – 60 time is not truly indicative of what a new owner can expect from a performance or exotic car, or even a muscle car.
# SEGMENT NO 4:
#  Instead, some believe the measure should include a range of times rather than one finite mark to which all cars of any particular model should be held. For instance, they believe a BMW M3 should have a listed time of 3.9 – 4.2 seconds and a Corvette Z06 should have a range from 3.6 to 4.0. These people believe that a range of numbers better represents what an owner can honestly expect to see when he or she takes delivery of a new vehicle. This contingent of car enthusiasts and engineers believes that there is no way for either the time to 60 mph or even a quarter mile time to be completely accurate, as there are simply too many variables that come into play. No matter if you are a 0 – 60 purist, or you believe that it is an inexact science, you can be sure that the measure itself will not be going away any time soon. It is still one of the biggest touted numbers for vehicles, and easier for people to relate to than horsepower and torque.
#
#  xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
# The query was: what is function of registry and the returned segments are:
# For method 1:
# SEGMENT NO 1:
#  Open 00000 file article translations
# For more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating
# systems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System
# Registry, review some possible attacks to it and ways to avoid them...
# Folders, files and paths- Files are the entries or information stored on your
# computer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by
# Microsoft with their products including system files for their series of operating systems...
# What are file extensions? - File extensions are unnoticed yet are very crucial parts of
# the computer world. But many are still unaware of the basic foundation and principles behind the remarkable wonders of computers...
# © Copyright 2021 extensionfile.net Privacy Policy. Terms of Service
# SEGMENT NO 2:
#  Install the application you found and check if it can open 00000 file
# Rate 00000 filepage: 54321
# 4/5based on 27ratings
# Populating this website with information and maintaining it is an ongoing process. We always welcome feedback and questions that can be submitted by visiting Contact Us page. However since there are many users visiting this website and because our team is quite small we may not be able to follow up personally on every request. Thank you for your understanding. Open 00000 file article translations
# For more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating
# systems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System
# Registry, review some possible attacks to it and ways to avoid them...
# Folders, files and paths- Files are the entries or information stored on your
# computer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by
# Microsoft with their products including system files for their series of operating systems...
# What are file extensions? -
# SEGMENT NO 3:
#  Comprehend level. Click on the activity hyperlink for a list of procedures to follow for using the activity. Activity Example or Non-Example? Purpose and Description
# The purpose of this activity is to allow students to practice classifying defined concepts. Students are given instances that represent Examples and Non-Examples. They must correctly name the defined concept described. Format
# Class
# Preparation and Materials Required
# __________________________________________________________________________________________________________
# List of Examples and Non-Examples for the defined concepts
# Instructor presentation materials
# Example and Non-Example Creation
# The purpose of this activity is to allow students to practice comprehending the characteristics of the defined concepts by creating Examples and Non-Examples of the defined concepts. Format
# Individual
# Pairs
# Small group
# Preparation and Materials Required
# Handouts of a list of defined concepts
# Student presentation materials
# __________________________________________________________________________________________________________
# Narrative Generation from Examples and Non-Examples
# The purpose of this activity is to allow students to practice and test their understanding of the characteristics of the defined concepts by creating narratives from a list of Examples and Non-Examples that summarize the lesson content. Format
# Individual
# Pairs
# Small group
# Preparation and Materials Required
# Handouts of Examples and Non-Examples of the defined concepts
# _________________________________________________________________________________________________________
# Procedures for Example or Non-Example? 1.
# SEGMENT NO 4:
#  What is 00J File? File extensions help computers locate correct application for specific files. Operating systems will not look into the content of the files to be opened, but instead, it will immediately locate the file extension of the file and locate for associated application that can open 00J files. This helps the computer to organize its functions and work much faster. Most operating systems (Windows) require the use of file extensions, but others do not (Unix). These file extensions are also beneficial for us. By simply looking at the filename, we can determine what type of information is stored to that and what applications can open these files. Have you noticed that when your computer acquires an unknown file, it will ask your permission to look for associated program to open it or look for these programs over the Internet? Yes! These file extensions make the work of the computer easy.
#
#
# For method 2:
# SEGMENT NO 1:
#  Open 00000 file article translations
# For more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating
# systems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System
# Registry, review some possible attacks to it and ways to avoid them...
# Folders, files and paths- Files are the entries or information stored on your
# computer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by
# Microsoft with their products including system files for their series of operating systems...
# What are file extensions? - File extensions are unnoticed yet are very crucial parts of
# the computer world. But many are still unaware of the basic foundation and principles behind the remarkable wonders of computers...
# © Copyright 2021 extensionfile.net Privacy Policy. Terms of Service
# SEGMENT NO 2:
#  Install the application you found and check if it can open 00000 file
# Rate 00000 filepage: 54321
# 4/5based on 27ratings
# Populating this website with information and maintaining it is an ongoing process. We always welcome feedback and questions that can be submitted by visiting Contact Us page. However since there are many users visiting this website and because our team is quite small we may not be able to follow up personally on every request. Thank you for your understanding. Open 00000 file article translations
# For more general information about how to open 00000 files, file extension 00000 and registry you can read one of the following articles: Windows registry- Windows registry is included in modern Windows operating
# systems to replace the older INI files which also contained system configuration. Let's concentrate on the structure and purpose of Windows System
# Registry, review some possible attacks to it and ways to avoid them...
# Folders, files and paths- Files are the entries or information stored on your
# computer. These are represented by binary coding and written on the tracks on a disk. Files are often represented by distinct icons, a normal practice done by
# Microsoft with their products including system files for their series of operating systems...
# What are file extensions? -
# SEGMENT NO 3:
#  Cameras are required to be on during SEL (social-emotional learning) and Live instruction (20-25 mins). If a teacher is unable to see or no responses are given when called, that will lead to the student being marked absent. Parents and families, please remember to check your parent portal to view your child’s attendance and grades. Online Registration System
# Since May 2020, Clayton County Public Schools (CCPS) has been offering anOnlineRegistration
# (OLR) process for students who areregisteringfor new/returning students who arenot currently enrolled with CCPS for the 2020-2021 school year. For more information regarding 2020-2021 Online Registration, please view the video at http://youtu.be/cct5TjGH7Twor visit the CCPS website (http://www.clayton.k12.ga.us). Registration Central Page
# https://www.clayton.k12.ga.us/cms/One.aspx?portalId=54515&pageId=237811
# CCPS Withdrawal Request Google Form
# For more information about counseling related topics, please visit the counseling page. Online Textbooks and Digital Resources
# We are working to make sure that all students and parents have access to textbooks and resources. As info, there are two documents you can reference. The first is the CCPS flyer about available resources. The second provides resources available for our students and parents at RHS.
# SEGMENT NO 4:
#  Explain that the purpose of this activity is to practice comprehending the characteristics of the defined concepts presented by classifying Examples and Non-Examples of the defined concepts. 2. Present a new Example or Non-Example (that has not been previously presented to students) of the defined concept from the list. 3. Have students determine if it is an Example or Non-Example and explain what characteristics make it an Example or Non-Example. 4. Provide feedback for the answer. 5. Repeat steps 2-4 until the students have correctly identified every defined concept from the list. 6.
#
#  xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# The query was: what is the fastest car in the? and the returned segments are:
# For method 1:
# SEGMENT NO 1:
#  But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version. But both measure the performance of a car. A lot goes into increasing 0-60 times in performance vehicles. As a normal rule of thumb, performance cars are considered those with 0-60 time of under 6 seconds, while Exotic cars will do 0-60 in 3 to 4 seconds. However, in most cases, a car isn’t simply “stuck with” the acceleration number with which it was born. Engineers and designers work tirelessly to provide better and better numbers with each progressive model of performance and exotic cars.
# SEGMENT NO 2:
#  But both measure the performance of a car. A lot goes into increasing 0-60 times in performance vehicles. As a normal rule of thumb, performance cars are considered those with 0-60 time of under 6 seconds, while Exotic cars will do 0-60 in 3 to 4 seconds. However, in most cases, a car isn’t simply “stuck with” the acceleration number with which it was born. Engineers and designers work tirelessly to provide better and better numbers with each progressive model of performance and exotic cars. But, even the back yard mechanic or muscle car enthusiast can determine the 0-60 times of their cars and make moves to improve them. The testing of acceleration is usually done on a closed course away from people other than the team that may be working on the specific car. This limits putting anyone in danger who is not part of the test or the ongoing project. Testers can use something as simple as a stop watch and the vehicle’s speedometer. This is probably good enough for the typical muscle car enthusiast who is just looking for an estimate of how much power his latest improvements will give him.
# SEGMENT NO 3:
#  0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews
# 0-60 Times
# There are many ways to measure the power a vehicle has – top speed, horsepower, foot-pounds of torque. Those are all important, but the most asked question is, “What’s the 0-60 time?” This is nothing more than a measure of how quickly a vehicle can reach the 60 mile per hour mark. It is a measure of acceleration of a vehicle. 0-60 times differ a great deal depending on the amount of power a motor puts out, of course. But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version.
# SEGMENT NO 4:
#  Instead, some believe the measure should include a range of times rather than one finite mark to which all cars of any particular model should be held. For instance, they believe a BMW M3 should have a listed time of 3.9 – 4.2 seconds and a Corvette Z06 should have a range from 3.6 to 4.0. These people believe that a range of numbers better represents what an owner can honestly expect to see when he or she takes delivery of a new vehicle. This contingent of car enthusiasts and engineers believes that there is no way for either the time to 60 mph or even a quarter mile time to be completely accurate, as there are simply too many variables that come into play. No matter if you are a 0 – 60 purist, or you believe that it is an inexact science, you can be sure that the measure itself will not be going away any time soon. It is still one of the biggest touted numbers for vehicles, and easier for people to relate to than horsepower and torque.
#
#
# For method 2:
# SEGMENT NO 1:
#  But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version. But both measure the performance of a car. A lot goes into increasing 0-60 times in performance vehicles. As a normal rule of thumb, performance cars are considered those with 0-60 time of under 6 seconds, while Exotic cars will do 0-60 in 3 to 4 seconds. However, in most cases, a car isn’t simply “stuck with” the acceleration number with which it was born. Engineers and designers work tirelessly to provide better and better numbers with each progressive model of performance and exotic cars.
# SEGMENT NO 2:
#  0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews
# 0-60 Times
# There are many ways to measure the power a vehicle has – top speed, horsepower, foot-pounds of torque. Those are all important, but the most asked question is, “What’s the 0-60 time?” This is nothing more than a measure of how quickly a vehicle can reach the 60 mile per hour mark. It is a measure of acceleration of a vehicle. 0-60 times differ a great deal depending on the amount of power a motor puts out, of course. But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power. The only other measure that comes close as far as how acceleration is commonly measures in cars in the United States is the quarter mile time. Enthusiasts will often ask about how quickly a car can get through a quarter mile, but that can be seen as less accurate a estimate of acceleration than the amount of time it takes a vehicle to reach the sixty miler per hour mark. The quarter mile time can often have more variable such as driver experience. The 0-60 mph speed is used as the standard in the United States, where the rest of the world prefers the 0-100 km version.
# SEGMENT NO 3:
#  For engineers testing a new exotic sports car, though, a simple estimate is not accurate enough. They want hard and fast 0-60 times, and they use much more highly-technical equipment to get their numbers. With the 0-60 figure being so important in automobile sales, they do everything possible to ensure their numbers are incredibly accurate. In professional testing situations, highly technical and accurate measuring devices are hooked to computers as the test is performed. The test is run in two different directions, to eliminate any influence of wind, an unseen downhill grade or any differences in traction. The average of these two times will be the recorded 0-60 time for the car. Doppler radar guns are used to ensure the tester is recording exact 0 -60 times. This leaves the driver to focus solely on running through the gears as precisely as possible and simply driving in a straight line. This allow for a more accurate measure, as does running the test first in one direction and then in the exact opposite direction. Some still feel, however, that listing one 0 – 60 time is not truly indicative of what a new owner can expect from a performance or exotic car, or even a muscle car.
# SEGMENT NO 4:
# ...
# SEGMENT NO 3:
#  As a result, the use of intelligence tests was acceptable in psychoeducational assessment as long as they followed all other procedural safeguards under federal law ( PASE v. Joseph P. Hannon, No. 74 C 3586 N.D. Ill. 1980 ). Luke S. and Hans S. v. Nix et al. ( 1982). In the state of Louisiana, all evaluations had to be completed within a 60-day time period. The plaintiffs in this case argued that thousands of students were not being appropriately ev
# SEGMENT NO 4:
#  In this case, California was mandated by the Court to correct bias in assessment procedures used with Chinese American and Mexican American students. Diana had three very important holdings that would later influence the enactment of federal special education laws: 1. If a student's primary language was not English, the student had to be tested in both English and his or her primary language. 2. Culturally unfair items had to be eliminated from all tests used in the assessment process. 3. If intelligence tests were to be used in the assessment process, they had to be developed to reflect Mexican American culture ( Diana v. State Board of Education, C-70: 37RFT (N.D. Cal., 1970 ).
#
#  xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# The query was: what plastics are recyclable in el paso tx and the returned segments are:
# For method 1:
# SEGMENT NO 1:
#  Let surface dry and then set it back up for the pet. Return the pet to the room. Are LA’s Totally Awesome All Purpose Cleaner ® containers recyclable? Please refer to the logo on the container. With a little bit of care much plastic can be recycled, and collection of plastics for recycling is increasing rapidly. The plastic industry has responded to this problem by developing a series of cryptic markers, commonly seen on the bottom of plastic containers. These markers do not mean the plastic can be recycled, these makers do not mean the container uses recycled plastic. You should place in your bin only those types of plastic listed by your local recycling agency! What is the shelf life of your products? All of our products are tested for a shelf life of a minimum of two years from the date of manufacture.
# SEGMENT NO 2:
#  The plastic industry has responded to this problem by developing a series of cryptic markers, commonly seen on the bottom of plastic containers. These markers do not mean the plastic can be recycled, these makers do not mean the container uses recycled plastic. You should place in your bin only those types of plastic listed by your local recycling agency! What is the shelf life of your products? All of our products are tested for a shelf life of a minimum of two years from the date of manufacture. However, we do recommend using the product within one year of opening it to guarantee freshness and efficacy. What is LA’s Totally Awesome All Purpose Cleaner ® made from? LA’s Totally Awesome All Purpose Cleaner ® is a blend of water, surfactant (surface-active) agents, color and scent. Surfactant agents lift grease and oil up off of the surface. LA’s Totally Awesome All Purpose Cleaner ® is a safe, naturally gentle soap, specially formulated for cleaning a variety of surfaces like floors, furniture, and other household surfaces.
# SEGMENT NO 3:
#  3. Using a sponge, scrubbing pad, or non-metallic bristle brush, wash down the surface. If the area to be cleaned is really large, start at the top and work downward, stopping after sections to "rinse" the surface so that the LA’s Totally Awesome All Purpose Cleaner ® doesn't dry on the surface. 4. Rinse each section, or the surface by either hosing down (if outside) or using a bucket of clean water and a cloth or sponge to rinse down
# 5. Let surface dry and then set it back up for the pet. Return the pet to the room. Are LA’s Totally Awesome All Purpose Cleaner ® containers recyclable? Please refer to the logo on the container. With a little bit of care much plastic can be recycled, and collection of plastics for recycling is increasing rapidly.
# SEGMENT NO 4:
#  Product may settle during shipment and develop an air pocket so it may take multiple clicks to get the product started. My home is on a septic system. Is it safe to use LA’s Totally Awesome All Purpose Cleaner ® for cleaning tubs and showers? Yes. Under normal household use, LA’s Totally Awesome All Purpose Cleaner ® won't harm the helpful bacterial and enzymes that are used to keep septic systems free-flowing. Is LA’s Totally Awesome All Purpose Cleaner ® a disinfectant? No LA’s Totally Awesome All Purpose Cleaner ® is not a disinfectant. How do I avoid the LA’s Totally Awesome All Purpose Cleaner ® container leaking? We use the best possible plastic for our products, so leaking is very unusual. The container may have been dropped either at the store or at the home.
#
#
# For method 2:
# SEGMENT NO 1:
#  Let surface dry and then set it back up for the pet. Return the pet to the room. Are LA’s Totally Awesome All Purpose Cleaner ® containers recyclable? Please refer to the logo on the container. With a little bit of care much plastic can be recycled, and collection of plastics for recycling is increasing rapidly. The plastic industry has responded to this problem by developing a series of cryptic markers, commonly seen on the bottom of plastic containers. These markers do not mean the plastic can be recycled, these makers do not mean the container uses recycled plastic. You should place in your bin only those types of plastic listed by your local recycling agency! What is the shelf life of your products? All of our products are tested for a shelf life of a minimum of two years from the date of manufacture.
# SEGMENT NO 2:
#  3. Using a sponge, scrubbing pad, or non-metallic bristle brush, wash down the surface. If the area to be cleaned is really large, start at the top and work downward, stopping after sections to "rinse" the surface so that the LA’s Totally Awesome All Purpose Cleaner ® doesn't dry on the surface. 4. Rinse each section, or the surface by either hosing down (if outside) or using a bucket of clean water and a cloth or sponge to rinse down
# 5. Let surface dry and then set it back up for the pet. Return the pet to the room. Are LA’s Totally Awesome All Purpose Cleaner ® containers recyclable? Please refer to the logo on the container. With a little bit of care much plastic can be recycled, and collection of plastics for recycling is increasing rapidly.
# SEGMENT NO 3:
#  Product may settle during shipment and develop an air pocket so it may take multiple clicks to get the product started. My home is on a septic system. Is it safe to use LA’s Totally Awesome All Purpose Cleaner ® for cleaning tubs and showers? Yes. Under normal household use, LA’s Totally Awesome All Purpose Cleaner ® won't harm the helpful bacterial and enzymes that are used to keep septic systems free-flowing. Is LA’s Totally Awesome All Purpose Cleaner ® a disinfectant? No LA’s Totally Awesome All Purpose Cleaner ® is not a disinfectant. How do I avoid the LA’s Totally Awesome All Purpose Cleaner ® container leaking? We use the best possible plastic for our products, so leaking is very unusual. The container may have been dropped either at the store or at the home.
# SEGMENT NO 4:
#  LA's Totally Awesome Products - FAQs
# Were can I buy LA’s Totally Awesome All Purpose Cleaner ®? You can buy the product at any
# 99 Cents only Store (in California, Nevada, Arizona, and Texas )
# Dollar Tree Store
# Dollar General Store
# Family Dollar Store
# or other discount stores in the US. In what sizes is LA’s Totally Awesome All Purpose Cleaner ® available? 16 oz LA’s Totally Awesome All Purpose Cleaner ®
# 20 oz LA’s Totally Awesome All Purpose Cleaner ®
# 22 oz LA’s Totally Awesome All Purpose Cleaner ®
# 32 oz LA’s Totally Awesome All Purpose Cleaner ®
# Can I buy the products online or directly from the company? At this time, Awesome Products does not offer our merchandise for sale over the internet or over the phone. Shipping and handling of the product in small quantity is very expensive and would cost a customer more than the price at the local stores. So please continue to shop for our products at your local 99 Cents only Store, Dollar Tree Store, Family Dollar store or other discount stores in the US. On what surfaces can I use LA’s Totally Awesome All Purpose Cleaner ® products? For Directions and applications please refer to the instructions on the bottle. In case of doubt be sure to test a small, hidden area before cleaning the entire surface in question and wipe it down with wet cloth / mop to check for any adverse effects.
#
#  xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# The query was: time in time zones in us and the returned segments are:
# For method 1:
# SEGMENT NO 1:
#  Muscat; Tblisi; Volgograd; Kabul
# +4:00
# 13:00 – 21:00
# ZP5
# Chesapeake Bay
# +5:00
# 14:00 – 22:00
# ZP6
# Chesapeake Bay
# +6:00
# 15:00 – 23:00
# WAST
# West Australian Standard
# +7:00
# 16:00 – 24:00
# CCT
# China Coast, Russia Zone 7, Hong Kong, Peking
# +8:00
# 17:00 – 01:00
# JST
# Japan Standard, Russia Zone 8
# +9:00
# 18:00 – 02:00
# GST
# Guam Standard, Russia Zone 9
# +10:00
# 19:00 – 03:00
#
#
# +11:00
# 20:00 – 04:00
# IDLE
# International Date Line East: Wellington, New
# Zealand
# +12:00
# 21:00 – 05:00
# NZST
# New Zealand Standard: Fiji
# +12:00
# 21:00 – 05:00
# NZT
# New Zealand: Marshall
# Islands
# +12:00
# 21:00 – 05:00
# Therefore, if something is due at 16:00 (4:00pm) GMT time, and you are located in Volgograd Russia on ZP4 time, you would have to deliver your work by 20:00 (8:00pm) your time (add four hours to the due date, according to the third column in the table above). Share|
# What are Time Zones? Well, we could ask what is time? To explain this, let us go
# to the beginning of what we can define as time.
# SEGMENT NO 2:
#  Fiji
# +12:00
# 21:00 – 05:00
# NZT
# New Zealand: Marshall
# Islands
# +12:00
# 21:00 – 05:00
# Therefore, if something is due at 16:00 (4:00pm) GMT time, and you are located in Volgograd Russia on ZP4 time, you would have to deliver your work by 20:00 (8:00pm) your time (add four hours to the due date, according to the third column in the table above). Share|
# What are Time Zones? Well, we could ask what is time? To explain this, let us go
# to the beginning of what we can define as time. Let us presume that, before the big bang, there was only
# energy, and no time. We can say that God was this energy. And "then" he decided
# to make things, so he converted this energy into massand hence was created the big bang, which was an explosion of the energy force turning
# into matter. Exploding outwards in all directions, and creating the universe, or many
# universes, and therefore dimensions, where time is considered the fourth dimension. Everything is relative.
# SEGMENT NO 3:
#  New York, NY, USA
# -5:00
# 04:00 – 12:00
# CST
# Central Standard: Mexico
# City, Mexico; Saskatchewan, Canada
# -6:00
# 03:00 – 11:00
# MST
# Mountain
# Standard
# -7:00
# 02:00 – 10:00
# PST
# Pacific Standard: Los Angeles, CA, USA
# -8:00
# 01:00 – 09:00
# YST
# Yukon
# Standard
# -9:00
# 24:00 – 08:00
# AHST, CAT, HST, EAST
# Alaska-Hawaii Standard; Central Alaska; Hawaii Standard; 09: East Australian Standard
# -10:00
# 23:00 – 07:00
# NT
# Nome
# -11:00
# 22:00 – 06:00
# IDLW
# International Date Line West
# -12:00
# 21:00 – 05:00
# CET
# Central European: Paris, France
# +1:00
# 10:00 – 18:00
# EET
# Eastern European, Russia Zone 1: Athens,
# Greece;
# SEGMENT NO 4:
#  Georgetown, Guyana
# -3:00
# 06:00 – 14:00
# AST
# Atlantic
# Standard: Caracas; La Paz
# -4:00
# 05:00 – 13:00
# EST
# Eastern Standard: Bogota; Lima, Peru; New York, NY, USA
# -5:00
# 04:00 – 12:00
# CST
# Central Standard: Mexico
# City, Mexico; Saskatchewan, Canada
# -6:00
# 03:00 – 11:00
# MST
# Mountain
# Standard
# -7:00
# 02:00 – 10:00
# PST
# Pacific Standard: Los Angeles, CA, USA
# -8:00
# 01:00 – 09:00
# YST
# Yukon
# Standard
# -9:00
# 24:00 – 08:00
# AHST, CAT, HST, EAST
# Alaska-Hawaii Standard; Central Alaska;
#
#
# For method 2:
# SEGMENT NO 1:
#  New York, NY, USA
# -5:00
# 04:00 – 12:00
# CST
# Central Standard: Mexico
# City, Mexico; Saskatchewan, Canada
# -6:00
# 03:00 – 11:00
# MST
# Mountain
# Standard
# -7:00
# 02:00 – 10:00
# PST
# Pacific Standard: Los Angeles, CA, USA
# -8:00
# 01:00 – 09:00
# YST
# Yukon
# Standard
# -9:00
# 24:00 – 08:00
# AHST, CAT, HST, EAST
# Alaska-Hawaii Standard; Central Alaska; Hawaii Standard; 09: East Australian Standard
# -10:00
# 23:00 – 07:00
# NT
# Nome
# -11:00
# 22:00 – 06:00
# IDLW
# International Date Line West
# -12:00
# 21:00 – 05:00
# CET
# Central European: Paris, France
# +1:00
# 10:00 – 18:00
# EET
# Eastern European, Russia Zone 1: Athens,
# Greece;
# SEGMENT NO 2:
#  Georgetown, Guyana
# -3:00
# 06:00 – 14:00
# AST
# Atlantic
# Standard: Caracas; La Paz
# -4:00
# 05:00 – 13:00
# EST
# Eastern Standard: Bogota; Lima, Peru; New York, NY, USA
# -5:00
# 04:00 – 12:00
# CST
# Central Standard: Mexico
# City, Mexico; Saskatchewan, Canada
# -6:00
# 03:00 – 11:00
# MST
# Mountain
# Standard
# -7:00
# 02:00 – 10:00
# PST
# Pacific Standard: Los Angeles, CA, USA
# -8:00
# 01:00 – 09:00
# YST
# Yukon
# Standard
# -9:00
# 24:00 – 08:00
# AHST, CAT, HST, EAST
# Alaska-Hawaii Standard; Central Alaska;
# SEGMENT NO 3:
#  Muscat; Tblisi; Volgograd; Kabul
# +4:00
# 13:00 – 21:00
# ZP5
# Chesapeake Bay
# +5:00
# 14:00 – 22:00
# ZP6
# Chesapeake Bay
# +6:00
# 15:00 – 23:00
# WAST
# West Australian Standard
# +7:00
# 16:00 – 24:00
# CCT
# China Coast, Russia Zone 7, Hong Kong, Peking
# +8:00
# 17:00 – 01:00
# JST
# Japan Standard, Russia Zone 8
# +9:00
# 18:00 – 02:00
# GST
# Guam Standard, Russia Zone 9
# +10:00
# 19:00 – 03:00
#
#
# +11:00
# 20:00 – 04:00
# IDLE
# International Date Line East: Wellington, New
# Zealand
# +12:00
# 21:00 – 05:00
# NZST
# New Zealand Standard: Fiji
# +12:00
# 21:00 – 05:00
# NZT
# New Zealand: Marshall
# Islands
# +12:00
# 21:00 – 05:00
# Therefore, if something is due at 16:00 (4:00pm) GMT time, and you are located in Volgograd Russia on ZP4 time, you would have to deliver your work by 20:00 (8:00pm) your time (add four hours to the due date, according to the third column in the table above). Share|
# What are Time Zones? Well, we could ask what is time? To explain this, let us go
# to the beginning of what we can define as time.
# SEGMENT NO 4:
#  Nairobi,
# Kenya; Riyadh, Saudi Arabia; Moscow, Russia; Tehran, Iran
# +3:00
# 12:00 – 20:00
# ZP4
# Russia Zone 3: Abu Dhabi, UAE; Muscat; Tblisi; Volgograd; Kabul
# +4:00
# 13:00 – 21:00
# ZP5
# Chesapeake Bay
# +5:00
# 14:00 – 22:00
# ZP6
# Chesapeake Bay
# +6:00
# 15:00 – 23:00
# WAST
# West Australian Standard
# +7:00
# 16:00 – 24:00
# CCT
# China Coast, Russia Zone 7, Hong Kong, Peking
# +8:00
# 17:00 – 01:00
# JST
# Japan Standard, Russia Zone 8
# +9:00
# 18:00 – 02:00
# GST
# Guam Standard, Russia Zone 9
# +10:00
# 19:00 – 03:00
#
#
# +11:00
# 20:00 – 04:00
# IDLE
# International Date Line East: Wellington, New
# Zealand
# +12:00
# 21:00 – 05:00
# NZST
# New Zealand Standard:
#
#  xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# ## LLM-as-a-judge

# %%
def llm_judge(segment1,segment2, query):
    prompt = "Which one of these segments is more related to this query: '" + query + "' DONT'T SUMMARIZE ANTHING JUST TELL ME WHICH YOU THINK IS MORE RELATED. 1/2? \n1. " + segment1 + "\n 2." + segment2
    url = "https://llm.srv.webis.de/api/generate"
    data = {
        "model": "llama3",
        "prompt": prompt,
        "stream": False
    }
    try:
        response = requests.post(url, json=data)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return None
    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
#method 1 is nonhyde method 2 is hyde kept anonymous for eval purposes
llm_text = ""
for topic in eval_dic.keys():
    nonhyde_segments = eval_dic[topic]["nonhyde"]
    hyde_segments = eval_dic[topic]["hyde"]


    for i in range(4):
        #only go to llm if there is a disagreement between the methods
        if nonhyde_segments[i].properties["docid"] != hyde_segments[i].properties["docid"]:
            nonhyde_s = nonhyde_segments[i].properties["segment"]
            hyde_s = hyde_segments[i].properties["segment"]

            llm_evaluation = llm_judge(nonhyde_s, hyde_s, topic)
            llm_text += "For segment: " + str(i+1) + "\n" 
            llm_text += llm_evaluation["response"] + "\n"



with open("llm_eval_text.txt", "w") as text_file:
   text_file.write(llm_text)

# %%
q = list(eval_dic.keys())[2]
s1 = eval_dic[q]["hyde"][0].properties["segment"]
s2 = eval_dic[q]["hyde"][1].properties["segment"]


llm_judge(s1, s2, q)["response"]
# Out:
# "I think segment 2 is more related to this query: 'definition of shelf life' because it explicitly answers the question about the shelf life of LA's Totally Awesome All Purpose Cleaner products."

# %%
q
# Out:
# 'what is the fastest car in the?'

# %%
s1
# Out:
# 'Let surface dry and then set it back up for the pet. Return the pet to the room. Are LA’s Totally Awesome All Purpose Cleaner ® containers recyclable? Please refer to the logo on the container. With a little bit of care much plastic can be recycled, and collection of plastics for recycling is increasing rapidly. The plastic industry has responded to this problem by developing a series of cryptic markers, commonly seen on the bottom of plastic containers. These markers do not mean the plastic can be recycled, these makers do not mean the container uses recycled plastic. You should place in your bin only those types of plastic listed by your local recycling agency! What is the shelf life of your products? All of our products are tested for a shelf life of a minimum of two years from the date of manufacture.'

# %%
s2
# Out:
# 'The plastic industry has responded to this problem by developing a series of cryptic markers, commonly seen on the bottom of plastic containers. These markers do not mean the plastic can be recycled, these makers do not mean the container uses recycled plastic. You should place in your bin only those types of plastic listed by your local recycling agency! What is the shelf life of your products? All of our products are tested for a shelf life of a minimum of two years from the date of manufacture. However, we do recommend using the product within one year of opening it to guarantee freshness and efficacy. What is LA’s Totally Awesome All Purpose Cleaner ® made from? LA’s Totally Awesome All Purpose Cleaner ® is a blend of water, surfactant (surface-active) agents, color and scent. Surfactant agents lift grease and oil up off of the surface. LA’s Totally Awesome All Purpose Cleaner ® is a safe, naturally gentle soap, specially formulated for cleaning a variety of surfaces like floors, furniture, and other household surfaces.'
